# %% [markdown]
# # Advanced Machine Learning - programming assignment 4
#
# *Due: Friday January 27*

# %% [markdown]
# **Please fill in:**
# * name 1 (student id 1)
# * name 2 (student id 2)

# %% [markdown]
# ### Further instructions:
# * Make sure your code is properly commented.
# * Submit your code in Blackboard using one of your accounts; we will put the grade in Blackboard for the other team member as well.
# * **Make sure to name the submitted file according to your and your collaborators last name.** (`submitter_collaborator.ipynb`)

# %% [markdown]
# ## Implementing the PC algorithm
# In this assignment, you will complete an implementation of the PC algorithm. After that, you will use it to discover causal relations in a data set. Each of these two parts is worth 5 points.

# %% [markdown]
# The PC algorithm will need to keep track of a PDAG. We will represent this PDAG by a numpy array `G` of booleans.
#
# The matrix `G` represents a graph as follows:
# * For all `x`, `G[x,x] == False`
# * `G[x,y] == False` and `G[y,x] == False` means: no edge between x and y
# * `G[x,y] == True` and `G[y,x] == True` means: an undirected edge x&mdash;y
# * `G[x,y] == True` and `G[y,x] == False`means: a directed edge x$\to$y

# %%
import numpy as np
import itertools
import graphviz  # Install with: conda install python-graphviz
from collections import Counter
from AML_assignment4_util import *

# %% [markdown]
# The graphviz can draw graphs to different file formats, or show them directly in the notebook. The function `graph_to_graphviz(G, node_names)` converts a numpy array of the form described above to a graph in graphviz format.

# %%
# Demonstration of graph_to_graphviz:
node_names = ['X', 'Y', 'Z', 'W']
G1 = np.zeros((4, 4), dtype=bool)
G1[0, 1] = G1[2, 1] = True  # two directed edges
G1[2, 3] = G1[3, 2] = True  # an undirected edge
d = graph_to_graphviz(G1, node_names)
d  # must be final line of code block to be displayed

# %% [markdown]
# Here is a Python class for performing the PC algorithm (when an object of this class is created and its `run` function is called). Add the missing code for phase 2, and implement phases 3 and 4. In the next section, you'll find some test cases to see if your code runs without errors and does what you expect it to.

# %%
class PC_algorithm:
    def __init__(self, independence_tester, verbose=0):
        # verbose can be 0 (silent), 1 (report independences), or 2 (also report dependences)
        self.independence_tester = independence_tester
        self.n = independence_tester.n_observed
        self.node_names = independence_tester.node_names
        self.verbose = verbose
        self.G = np.logical_not(np.eye(self.n, dtype=bool))
        self.sepset = dict()


    def skeleton_search(self):
        # PHASE II: Skeleton search
        # Note: Adj(X) in the slides means: all nodes adjacent to X in the current graph G
        for k in range(self.n - 1):
            for x in range(self.n):
                for y in range(self.n):
                    if not self.G[x, y]:
                        continue
                    # Try all subsets S of Adj(x) \ {y} with |S|=k,
                    # until an independence is found.
                    # Hint: use itertools.combinations

                    neighbours = list(
                        set([n for n in range(len(self.node_names)) for n2 in range(len(self.node_names)) if
                             ((n != x) and (n != y) and (n2 != x) and (n2 != y))]))

                    Subsets = itertools.combinations(neighbours, k)

                    # Your code here (1 point)
                    #AB,AC,Ad, k=0
                    #AB,AC,ad  {c} {d}, {b} {d}, {b}, {c}    k=1
                    for S in Subsets:  # replace this line by your code
                        indep = self.independence_tester.test_independence(x, y, S)
                        if indep:
                            if self.verbose >= 1:
                                print("independence found: {0} and {1} given {{{2}}}"
                                      .format(self.node_names[x], self.node_names[y],
                                              ", ".join([self.node_names[v] for v in S])))
                            # Remove this edge.

                            self.G[x, y] = self.G[y, x] = False
                            # We use frozensets as keys in the dictionary self.sepset,
                            # because ordinary sets can't be used as keys to dictionaries.
                            self.sepset[frozenset([x, y])] = S

                            break
                        else:
                            if self.verbose >= 2:
                                print("dependence found: {0} and {1} given {{{2}}}"
                                      .format(self.node_names[x], self.node_names[y],
                                              ", ".join([self.node_names[v] for v in S])))

            # Do we need to continue with larger k?
            max_S_size = np.sum(self.G, axis=0) - 1
            if np.all(max_S_size < k + 1):
                break
        print(self.sepset)
        return

    def orient_v_structures(self):
        # PHASE III: Orient v-structures
        # Something to watch out for:
        # If the data are not faithful to any graph, the algorithm may end up trying
        # to orient a single edge in two different ways. You can choose either
        # orientation if this happens. But make sure not to accidentally delete such an edge!
        for x in range(len(self.node_names)):
            for y in range(len(self.node_names)):
                if self.G[x, y] or x == y or self.G[y, x]:
                    continue
                for z in range(len(self.node_names)):
                    if (self.G[z, x] or self.G[x, z]) and (self.G[z, y] or self.G[y, z]):
                        if (z not in self.sepset[frozenset([x, y])]):
                            self.G[x, z] = True
                            self.G[z, x] = False
                            self.G[y, z] = True
                            self.G[z, y] = False

        return

    def orientation_rules(self):
        # PHASE IV: Orientation rules
        for x in range(len(self.node_names)):
            for y in range(len(self.node_names)):
                if self.G[x, y] == self.G[y, x] == True and x != y:  # Check if there is an undirected edge between X and Y.
                    for z in range(len(self.node_names)):

                        if z == x or z == y:
                            continue

                        if self.G[z, x] == True and self.G[x, z] == False:  # Check if Z -> X

                            if self.G[y,z] == False and self.G[z,y] == False:
                                self.G[x, y] = True
                                self.G[y,x] = False
                                break

                            if self.G[y,z] == True and self.G[z,y] == False:
                                self.G[x, y] = False
                                self.G[y,x] = True
                                break


                        for q in range(len(self.node_names)):
                            if q == x or q == y or q == z:
                                continue
                            if (self.G[x, z] and self.G[z, x]) and (self.G[z, y] and not (self.G[y, z])):
                                if (self.G[x, q] and self.G[q, x]) and (self.G[q, y] and not (self.G[y, q])):
                                    self.G[x, y] = True
                                    self.G[y, x] = False

        return

    def run(self):
        # The initialization step has already been performed by the __init__ method.
        # Perform the other phases one by one. Each of the following functions
        # modifies self.G, which represents the graph.
        self.skeleton_search()
        self.orient_v_structures()
        self.orientation_rules()

        return self.G

# %% [markdown]
# ## Testing the PC implementation
#
# To verify that the algorithm is working correctly, we will feed it output from an *oracle* instead of conditional independence test results from a data set. The oracle knows what the true graph is, and mimics the conditional independence test results that we would get for data that is Markov and faithful to that graph. In this situation, the PC algorithm will recover the Markov equivalence class of the true graph.

# %%
class IndependenceOracle:
    def __init__(self, true_G, node_names, n_observed=None):
        self.G = true_G
        self.n = true_G.shape[0]
        self.n_observed = n_observed if n_observed is not None else self.n
        self.node_names = node_names

    def test_independence(self, x, y, S):
        S_mask = np.zeros(self.n, dtype=bool)
        np.put(S_mask, S, True)
        return is_d_separated(self.G, x, y, S_mask)

# %% [markdown]
# We will compare the output of PC to the oracle's true graph for the graph `G1` we saw before, and for several other graphs. (You can add more tests to help chase down any bugs.)

# %%
oracle = IndependenceOracle(G1, node_names)
A = PC_algorithm(oracle, verbose=0)
G = A.run()
print("PASS" if np.all(G == G1) else "FAIL")
graph_to_graphviz(G, oracle.node_names)
# Out:
# {frozenset({0, 2}): (), frozenset({0, 3}): (), frozenset({1, 3}): (2,)}
# PASS

# %%
G2 = np.zeros((4, 4), dtype=bool)
G2[0, 2] = G2[1, 2] = G2[2, 3] = True
graph_to_graphviz(G2, node_names)

# %%
oracle = IndependenceOracle(G2, node_names)
A = PC_algorithm(oracle)
G = A.run()
print("PASS" if np.all(G == G2) else "FAIL")
graph_to_graphviz(G, oracle.node_names)
# Out:
# {frozenset({0, 1}): (), frozenset({0, 3}): (2,), frozenset({1, 3}): (2,)}
# PASS

# %%
G3 = np.zeros((4, 4), dtype=bool)
G3[0, 2] = G3[1, 2] = G3[1, 3] = G3[2, 3] = True
graph_to_graphviz(G3, node_names)

# %%
oracle = IndependenceOracle(G3, node_names)
A = PC_algorithm(oracle)
G = A.run()
print("PASS" if np.all(G == G3) else "FAIL")
graph_to_graphviz(G, oracle.node_names)
# Out:
# {frozenset({0, 1}): (), frozenset({0, 3}): (1, 2)}
# PASS

# %%
G4 = np.logical_not(np.eye(4, dtype=bool))
G4[0, 1] = G4[1, 0] = False
G4[3, 0] = G4[3, 1] = G4[3, 2] = False
graph_to_graphviz(G4, node_names)

# %%
oracle = IndependenceOracle(G4, node_names)
A = PC_algorithm(oracle)
G = A.run()
print("PASS" if np.all(G == G4) else "FAIL")
graph_to_graphviz(G, oracle.node_names)
# Out:
# {frozenset({0, 1}): (2,)}
# PASS

# %%
# Example of a case for which no DAG exists that is Markov and faithful to the distribution.
# L is a latent variable that the PC algorithm won't know about. PC's output should be either
# X --> Y --> Z <-- W or
# X --> Y <-- Z <-- W.
# If there is no edge between Y and Z in your output, this most likely indicates a bug in
# your implementation of phase III.
G5 = np.zeros((5, 5), dtype=bool)
G5[0, 1] = G5[4, 1] = True
G5[3, 2] = G5[4, 2] = True
graph_to_graphviz(G5, ['X', 'Y', 'Z', 'W', 'L'])

# %%
oracle = IndependenceOracle(G5, node_names, n_observed=4)
A = PC_algorithm(oracle)
G = A.run()
print("PASS" if G[0, 1] and G[3, 2] and (G[1, 2] or G[2, 1]) and np.sum(np.logical_or(G, G.T)) == 6 else "FAIL")
graph_to_graphviz(G, oracle.node_names)
# Out:
# {frozenset({0, 2}): (), frozenset({0, 3}): (), frozenset({1, 3}): ()}
# PASS

# %% [markdown]
# ## Running PC on data
# In this second part of the assignment, you will apply the PC algorithm to the biological dataset of Sachs et al. (2005). In this dataset, the columns represent 11 different proteins, which were measured in thousands of human immune system cells. Each row is a single cell. The cells were prepared in different ways, by adding different chemicals some time before the measurements were made. A twelfth column, labeled `experiment`, indicates in which way that cell was prepared. We can think of `experiment=1` as denoting the observational data, and other values of `experiment` (2 through 14) as various interventional datasets.

# %%
import pandas as pd

all_data = pd.read_csv("sachs2005_combined.csv", sep='\t')
# Transform all columns except 'experiment' by taking the logarithm of 10 + the original value
all_data.loc[:, all_data.columns != 'experiment'] = np.log(10 + all_data.loc[:, all_data.columns != 'experiment'])
# Out:
# c:\Users\niels\Anaconda3\lib\site-packages\pandas\compat\_optional.py:138: UserWarning: Pandas requires version '2.7.0' or newer of 'numexpr' (version '2.6.9' currently installed).
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# We will apply the PC algorithm to just the observational data.
#
# Make a new dataframe containing only the data where experiment equals 1. Remove the `experiment` column from this dataframe. Check the shape of your dataframe: it should be `(853, 11)`.

# %%
# Your code here (0.5 point)
experiment_data = all_data.loc[all_data['experiment'] == 1]
experiment_data = experiment_data.iloc[:, :-1]

print(experiment_data.shape)
# Out:
# (853, 11)

# %% [markdown]
# For the next part, you will need to install the package [tigramite](https://github.com/jakobrunge/tigramite). Here are three different ways in which you might be able to install it, in the order in which we recommend you to try them:
#
# 1. `conda install -c egilliesix tigramite`
#
# 2. `conda install git pip`
# `pip install git+git://github.com/jakobrunge/tigramite.git`
#
# 3. If not in a conda environment, follow the README on github.
#
# To run the PC algorithm on data, we need to perform (conditional) independence tests. Tigramite implements several such tests. The simplest of these tests is `ParCorr()`. It assumes the data come from a linear structural causal model, which they actually don't. We will use it anyway, because the alternatives (such as `CMIknn()` (Runge, 2018)) are more effort to install and orders of magnitude slower, while `ParCorr()` usually already gives decent results.
#
# As a statistical test, a conditional independence test works by computing a p-value. If a conditional independence exists, this p-value will be approximately uniformly distributed on the interval between 0 and 1. If the variables being tested are conditionally dependent, the p-value will be close to 0. PC wants to know a binary answer, so we will pick some threshold alpha and declare an independence if the p-value is larger than alpha.
#
# In statistical testing, alpha is often taken to be 0.05 or smaller. For PC, it may be more appropriate to pick a larger alpha instead. This is because as soon as PC finds a (conditional) independence between two variables, it will delete the edge between them and do no more tests between those two variables. If this happens while it shouldn't have, PC can't put the edge back. But in the reverse situation, if PC leaves an edge in place while it should have deleted it, there is still a possibility that the edge will be deleted later, when another test between those two variables reports a more convincing independence.

# %%
# !pip install tigramite
# Out:
# Collecting tigramite
#   Downloading tigramite-5.1.0.3-py3-none-any.whl (197 kB)
#      -------------------------------------- 197.3/197.3 kB 2.0 MB/s eta 0:00:00
#   Downloading tigramite-5.1.0.2-py3-none-any.whl (197 kB)
#      -------------------------------------- 197.5/197.5 kB 4.0 MB/s eta 0:00:00
#   Downloading tigramite-5.1.0.0-py3-none-any.whl (197 kB)
#      -------------------------------------- 197.5/197.5 kB 3.0 MB/s eta 0:00:00
#   Downloading tigramite-5.0.1.16-py3-none-any.whl (187 kB)
#      -------------------------------------- 187.5/187.5 kB 3.8 MB/s eta 0:00:00
#   Downloading tigramite-5.0.1.15-py3-none-any.whl (187 kB)
#      ------------------------------------- 187.5/187.5 kB 11.1 MB/s eta 0:00:00
#   Downloading tigramite-5.0.1.13-py3-none-any.whl (187 kB)
#      -------------------------------------- 187.4/187.4 kB 3.9 MB/s eta 0:00:00
#   Downloading tigramite-5.0.1.10-py3-none-any.whl (187 kB)
#      -------------------------------------- 187.4/187.4 kB 5.7 MB/s eta 0:00:00
#   Downloading tigramite-5.0.1.5-py3-none-any.whl (183 kB)
#      -------------------------------------- 183.7/183.7 kB 5.6 MB/s eta 0:00:00
#   Downloading tigramite-5.0.1.3-py3-none-any.whl (183 kB)
#      ------------------------------------- 183.3/183.3 kB 10.8 MB/s eta 0:00:00
#   Downloading tigramite-5.0.0.3-py3-none-any.whl (181 kB)
#      ------------------------------------- 181.4/181.4 kB 10.7 MB/s eta 0:00:00
# Requirement already satisfied: numpy in c:\users\niels\anaconda3\lib\site-packages (from tigramite) (1.21.6)
# Requirement already satisfied: numba in c:\users\niels\anaconda3\lib\site-packages (from tigramite) (0.44.1)
# Requirement already satisfied: scipy in c:\users\niels\anaconda3\lib\site-packages (from tigramite) (1.2.1)
# Requirement already satisfied: six in c:\users\niels\appdata\roaming\python\python37\site-packages (from tigramite) (1.15.0)
# Requirement already satisfied: llvmlite>=0.29.0 in c:\users\niels\anaconda3\lib\site-packages (from numba->tigramite) (0.29.0)
# Installing collected packages: tigramite
# Successfully installed tigramite-5.0.0.3
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\niels\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\users\niels\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\niels\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\users\niels\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\niels\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\users\niels\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\niels\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\users\niels\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -pencv-python (c:\users\niels\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ensorflow (c:\users\niels\anaconda3\lib\site-packages)
# WARNING: There was an error checking the latest version of pip.

# %%
from tigramite.independence_tests import ParCorr  #, CMIknn
import tigramite.data_processing as pp


# Importing these may give some warnings (e.g. 'Could not import r-package RCIT'),
# but most of these warnings can be ignored because we are not using the mentioned packages.

class IndependenceTester:
    def __init__(self, data, cond_ind_test, alpha, verbose=2, n_observed=None):
        # data: a pandas dataframe
        # cond_ind_test: an independence test from tigramite, e.g. ParCorr()
        # alpha: the significance level to which the p-values are compared

        # tigramite uses its own kind of dataframe, so convert the data to that format
        df_tigramite = pp.DataFrame(data.to_numpy(), var_names=data.columns)
        self.cond_ind_test = cond_ind_test
        self.cond_ind_test.set_dataframe(df_tigramite)
        self.n = data.shape[1]
        self.n_observed = n_observed if n_observed is not None else self.n
        self.verbose = verbose
        self.node_names = data.columns
        self.alpha = alpha

    def test_independence(self, x, y, S):
        val, pval = self.cond_ind_test.run_test(X=[(x, 0)],
                                                Y=[(y, 0)],
                                                Z=[(z, 0) for z in S])
        test_result = pval > self.alpha
        if self.verbose >= 2 or (self.verbose >= 1 and test_result):
            print("test: {0} and {1} given {2} -> pval={3}".format(self.node_names[x], self.node_names[y],
                                                                   ", ".join([self.node_names[v] for v in S]),
                                                                   pval))
        return test_result

# %% [markdown]
# Using an IndependenceTester object (which works similarly to the IndependenceOracle we used earlier), run the PC algorithm on the observational data. Display the graph that comes out. You may experiment with different values of alpha; the graph you get should either be connected (i.e. consist of one [connected component](https://en.wikipedia.org/wiki/Component_%28graph_theory%29)), or have just two connected components.

# %%
# Your code here (1 point)
tester = IndependenceTester(experiment_data, ParCorr(),0.2)
A = PC_algorithm(tester)
G = A.run()
graph_to_graphviz(G, tester.node_names)
# Out:
# test: praf and pmek given  -> pval=6.283143797792866e-129
# test: praf and plcg given  -> pval=0.5373868874563723
# test: praf and PIP2 given  -> pval=0.9727919297048809
# test: praf and PIP3 given  -> pval=0.3346593897889285
# test: praf and perk given  -> pval=0.6217936401751424
# test: praf and pakts473 given  -> pval=0.32132338584276826
# test: praf and PKA given  -> pval=0.9668029258427128
# test: praf and PKC given  -> pval=0.20877767649396428
# test: praf and P38 given  -> pval=0.09366579153448522
# test: praf and pjnk given  -> pval=0.5819563650509854
# test: pmek and praf given  -> pval=6.283143797792866e-129
# test: pmek and plcg given  -> pval=0.8066845247629106
# test: pmek and PIP2 given  -> pval=0.2629515450360251
# test: pmek and PIP3 given  -> pval=0.047159853623461576
# test: pmek and perk given  -> pval=0.5704656795447963
# test: pmek and pakts473 given  -> pval=0.696144749771238
# test: pmek and PKA given  -> pval=0.878013377232139
# test: pmek and PKC given  -> pval=0.24548793643262445
# test: pmek and P38 given  -> pval=0.21089683676303728
# test: pmek and pjnk given  -> pval=0.2150359904180923
# test: plcg and PIP2 given  -> pval=0.014760116617122909
# test: plcg and PIP3 given  -> pval=0.0001086244058075753
# test: plcg and perk given  -> pval=0.29940931183763986
# test: plcg and pakts473 given  -> pval=0.4360089287896882
# test: plcg and PKA given  -> pval=0.6791534824965264
# test: plcg and PKC given  -> pval=0.7514732463603042
# test: plcg and P38 given  -> pval=0.9884312693084769
# test: plcg and pjnk given  -> pval=0.08191083255848276
# test: PIP2 and plcg given  -> pval=0.014760116617122909
# test: PIP2 and PIP3 given  -> pval=6.640724688681568e-31
# test: PIP2 and perk given  -> pval=0.2567905663208524
# test: PIP2 and pakts473 given  -> pval=0.641457079100312
# test: PIP2 and PKA given  -> pval=0.4541744146187495
# test: PIP2 and PKC given  -> pval=0.5810493328129226
# test: PIP2 and P38 given  -> pval=0.8394313692867978
# test: PIP2 and pjnk given  -> pval=0.8359516510501769
# test: PIP3 and pmek given  -> pval=0.047159853623461576
# test: PIP3 and plcg given  -> pval=0.0001086244058075753
# test: PIP3 and PIP2 given  -> pval=6.640724688681568e-31
# test: PIP3 and perk given  -> pval=0.26600053639646853
# test: PIP3 and pakts473 given  -> pval=0.24197169954142803
# test: PIP3 and PKA given  -> pval=0.9987535723897433
# test: PIP3 and PKC given  -> pval=0.6744562666085029
# test: PIP3 and P38 given  -> pval=0.9038552784559979
# test: PIP3 and pjnk given  -> pval=0.479021562917328
# test: perk and pakts473 given  -> pval=1.7027177448400614e-264
# test: perk and PKA given  -> pval=7.112938819178581e-27
# test: perk and PKC given  -> pval=0.6181218753841426
# test: perk and P38 given  -> pval=0.5038306351503568
# test: perk and pjnk given  -> pval=0.32196709252044703
# test: pakts473 and perk given  -> pval=1.7027177448400614e-264
# test: pakts473 and PKA given  -> pval=1.7181586613459158e-38
# test: pakts473 and PKC given  -> pval=0.4382659417249426
# test: pakts473 and P38 given  -> pval=0.9757079496959221
# test: pakts473 and pjnk given  -> pval=0.5651487944612902
# test: PKA and perk given  -> pval=7.112938819178581e-27
# test: PKA and pakts473 given  -> pval=1.7181586613459158e-38
# test: PKA and PKC given  -> pval=0.2720205079127226
# test: PKA and P38 given  -> pval=0.4308722466820032
# test: PKA and pjnk given  -> pval=0.33883752654591914
# test: PKC and P38 given  -> pval=8.847651325236589e-116
# test: PKC and pjnk given  -> pval=2.1669122412806103e-15
# test: P38 and praf given  -> pval=0.09366579153448522
# test: P38 and PKC given  -> pval=8.847651325236589e-116
# test: P38 and pjnk given  -> pval=0.014289554530539438
# test: pjnk and plcg given  -> pval=0.08191083255848276
# test: pjnk and PKC given  -> pval=2.1669122412806103e-15
# test: pjnk and P38 given  -> pval=0.014289554530539438
# test: praf and pmek given plcg -> pval=8.807937771800402e-129
# test: praf and pmek given PIP2 -> pval=5.030183766211851e-129
# test: praf and pmek given PIP3 -> pval=1.171053296761576e-128
# test: praf and pmek given perk -> pval=4.5261607122994677e-129
# test: praf and pmek given pakts473 -> pval=8.700646286905379e-129
# test: praf and pmek given PKA -> pval=8.828512233774518e-129
# test: praf and pmek given PKC -> pval=1.6129702798226958e-128
# test: praf and pmek given P38 -> pval=1.92919696940381e-128
# test: praf and pmek given pjnk -> pval=1.3645391235360691e-129
# test: praf and P38 given pmek -> pval=0.2629169015855698
# test: pmek and praf given plcg -> pval=8.807937771800402e-129
# test: pmek and praf given PIP2 -> pval=5.030183766211851e-129
# test: pmek and praf given PIP3 -> pval=1.171053296761576e-128
# test: pmek and praf given perk -> pval=4.5261607122994677e-129
# test: pmek and praf given pakts473 -> pval=8.700646286905379e-129
# test: pmek and praf given PKA -> pval=8.828512233774518e-129
# test: pmek and praf given PKC -> pval=1.6129702798226958e-128
# test: pmek and praf given P38 -> pval=1.92919696940381e-128
# test: pmek and praf given pjnk -> pval=1.3645391235360691e-129
# test: pmek and PIP3 given praf -> pval=0.06606848342058758
# test: pmek and PIP3 given plcg -> pval=0.04899460255452561
# test: pmek and PIP3 given PIP2 -> pval=0.09204798920888202
# test: pmek and PIP3 given perk -> pval=0.044725042243271125
# test: pmek and PIP3 given pakts473 -> pval=0.04886664701358691
# test: pmek and PIP3 given PKA -> pval=0.04728775028331408
# test: pmek and PIP3 given PKC -> pval=0.04525655814663446
# test: pmek and PIP3 given P38 -> pval=0.04650930798540905
# test: pmek and PIP3 given pjnk -> pval=0.043770723362747614
# test: plcg and PIP2 given praf -> pval=0.014825988893488138
# test: plcg and PIP2 given pmek -> pval=0.015131096601754485
# test: plcg and PIP2 given PIP3 -> pval=0.29258985548950467
# test: plcg and PIP3 given praf -> pval=0.00011785949933376413
# test: plcg and PIP3 given pmek -> pval=0.0001131563895995443
# test: plcg and PIP3 given PIP2 -> pval=0.0014566026634638609
# test: plcg and PIP3 given perk -> pval=9.092045886705032e-05
# test: plcg and PIP3 given pakts473 -> pval=9.445742164893503e-05
# test: plcg and PIP3 given PKA -> pval=0.00010947687114614903
# test: plcg and PIP3 given PKC -> pval=0.00010730469922934593
# test: plcg and PIP3 given P38 -> pval=0.0001096005231518148
# test: plcg and PIP3 given pjnk -> pval=0.00012633591292423468
# test: plcg and pjnk given praf -> pval=0.08403978095703178
# test: plcg and pjnk given pmek -> pval=0.07998930143328795
# test: plcg and pjnk given PIP2 -> pval=0.08408776650246755
# test: plcg and pjnk given PIP3 -> pval=0.09690573141277112
# test: plcg and pjnk given perk -> pval=0.07571167455199723
# test: plcg and pjnk given pakts473 -> pval=0.07925198567886464
# test: plcg and pjnk given PKA -> pval=0.0843120687342488
# test: plcg and pjnk given PKC -> pval=0.086074787011674
# test: plcg and pjnk given P38 -> pval=0.08122603934659402
# test: PIP2 and PIP3 given praf -> pval=6.7350490356590716e-31
# test: PIP2 and PIP3 given pmek -> pval=1.2489055624816364e-30
# test: PIP2 and PIP3 given plcg -> pval=8.191297677244624e-30
# test: PIP2 and PIP3 given perk -> pval=3.2764794475822404e-31
# test: PIP2 and PIP3 given pakts473 -> pval=4.909571721783081e-31
# test: PIP2 and PIP3 given PKA -> pval=6.847343734407131e-31
# test: PIP2 and PIP3 given PKC -> pval=6.215273560399731e-31
# test: PIP2 and PIP3 given P38 -> pval=7.2324261822309395e-31
# test: PIP2 and PIP3 given pjnk -> pval=7.3272505616433e-31
# test: PIP3 and pmek given praf -> pval=0.06606848342058758
# test: PIP3 and pmek given plcg -> pval=0.04899460255452561
# test: PIP3 and pmek given PIP2 -> pval=0.09204798920888202
# test: PIP3 and pmek given perk -> pval=0.044725042243271125
# test: PIP3 and pmek given pakts473 -> pval=0.04886664701358691
# test: PIP3 and pmek given PKA -> pval=0.04728775028331408
# test: PIP3 and pmek given PKC -> pval=0.04525655814663446
# test: PIP3 and pmek given P38 -> pval=0.04650930798540905
# test: PIP3 and pmek given pjnk -> pval=0.043770723362747614
# test: PIP3 and plcg given praf -> pval=0.00011785949933376413
# test: PIP3 and plcg given pmek -> pval=0.0001131563895995443
# test: PIP3 and plcg given PIP2 -> pval=0.0014566026634638609
# test: PIP3 and plcg given perk -> pval=9.092045886705032e-05
# test: PIP3 and plcg given pakts473 -> pval=9.445742164893503e-05
# test: PIP3 and plcg given PKA -> pval=0.00010947687114614903
# test: PIP3 and plcg given PKC -> pval=0.00010730469922934593
# test: PIP3 and plcg given P38 -> pval=0.0001096005231518148
# test: PIP3 and plcg given pjnk -> pval=0.00012633591292423468
# test: PIP3 and PIP2 given praf -> pval=6.7350490356590716e-31
# test: PIP3 and PIP2 given pmek -> pval=1.2489055624816364e-30
# test: PIP3 and PIP2 given plcg -> pval=8.191297677244624e-30
# test: PIP3 and PIP2 given perk -> pval=3.2764794475822404e-31
# test: PIP3 and PIP2 given pakts473 -> pval=4.909571721783081e-31
# test: PIP3 and PIP2 given PKA -> pval=6.847343734407131e-31
# test: PIP3 and PIP2 given PKC -> pval=6.215273560399731e-31
# test: PIP3 and PIP2 given P38 -> pval=7.2324261822309395e-31
# test: PIP3 and PIP2 given pjnk -> pval=7.3272505616433e-31
# test: perk and pakts473 given praf -> pval=2.9470022432538377e-264
# test: perk and pakts473 given pmek -> pval=7.395997135572639e-265
# test: perk and pakts473 given plcg -> pval=4.5436009774965945e-264
# test: perk and pakts473 given PIP2 -> pval=2.198714754087709e-264
# test: perk and pakts473 given PIP3 -> pval=6.31428734092594e-264
# test: perk and pakts473 given PKA -> pval=2.468083358340046e-239
# test: perk and pakts473 given PKC -> pval=3.6780630616025365e-264
# test: perk and pakts473 given P38 -> pval=1.8469503526442663e-264
# test: perk and pakts473 given pjnk -> pval=3.4467864918061866e-264
# test: perk and PKA given praf -> pval=7.543906853579372e-27
# test: perk and PKA given pmek -> pval=7.164954037055708e-27
# test: perk and PKA given plcg -> pval=5.826226697211165e-27
# test: perk and PKA given PIP2 -> pval=9.427969733719193e-27
# test: perk and PKA given PIP3 -> pval=6.961977661644026e-27
# test: perk and PKA given pakts473 -> pval=0.3937872695254775
# test: pakts473 and perk given praf -> pval=2.9470022432538377e-264
# test: pakts473 and perk given pmek -> pval=7.395997135572639e-265
# test: pakts473 and perk given plcg -> pval=4.5436009774965945e-264
# test: pakts473 and perk given PIP2 -> pval=2.198714754087709e-264
# test: pakts473 and perk given PIP3 -> pval=6.31428734092594e-264
# test: pakts473 and perk given PKA -> pval=2.468083358340046e-239
# test: pakts473 and perk given PKC -> pval=3.6780630616025365e-264
# test: pakts473 and perk given P38 -> pval=1.8469503526442663e-264
# test: pakts473 and perk given pjnk -> pval=3.4467864918061866e-264
# test: pakts473 and PKA given praf -> pval=1.7399024829647947e-38
# test: pakts473 and PKA given pmek -> pval=1.9204063398399243e-38
# test: pakts473 and PKA given plcg -> pval=1.4737084633031845e-38
# test: pakts473 and PKA given PIP2 -> pval=2.0879986215382093e-38
# test: pakts473 and PKA given PIP3 -> pval=1.634068922014865e-38
# test: pakts473 and PKA given perk -> pval=2.2329639752391876e-13
# test: pakts473 and PKA given PKC -> pval=2.420078296917949e-38
# test: pakts473 and PKA given P38 -> pval=1.7506471443333861e-38
# test: pakts473 and PKA given pjnk -> pval=2.201845691147912e-38
# test: PKA and pakts473 given praf -> pval=1.7399024829647947e-38
# test: PKA and pakts473 given pmek -> pval=1.9204063398399243e-38
# test: PKA and pakts473 given plcg -> pval=1.4737084633031845e-38
# test: PKA and pakts473 given PIP2 -> pval=2.0879986215382093e-38
# test: PKA and pakts473 given PIP3 -> pval=1.634068922014865e-38
# test: PKA and pakts473 given perk -> pval=2.2329639752391876e-13
# test: PKA and pakts473 given PKC -> pval=2.420078296917949e-38
# test: PKA and pakts473 given P38 -> pval=1.7506471443333861e-38
# test: PKA and pakts473 given pjnk -> pval=2.201845691147912e-38
# test: PKC and P38 given praf -> pval=2.6185896983736446e-115
# test: PKC and P38 given pmek -> pval=2.1588290151151913e-115
# test: PKC and P38 given plcg -> pval=1.160328666131391e-115
# test: PKC and P38 given PIP2 -> pval=9.032513066953797e-116
# test: PKC and P38 given PIP3 -> pval=1.183074250241154e-115
# test: PKC and P38 given perk -> pval=5.89057289556949e-116
# test: PKC and P38 given pakts473 -> pval=9.048299433455144e-116
# test: PKC and P38 given PKA -> pval=1.639552393258639e-115
# test: PKC and P38 given pjnk -> pval=7.581133801136407e-118
# test: PKC and pjnk given praf -> pval=2.5581086032174886e-15
# test: PKC and pjnk given pmek -> pval=1.3175122249405834e-15
# test: PKC and pjnk given plcg -> pval=2.3392031949957236e-15
# test: PKC and pjnk given PIP2 -> pval=2.294816634989377e-15
# test: PKC and pjnk given PIP3 -> pval=2.009010007821291e-15
# test: PKC and pjnk given perk -> pval=2.4767006990247617e-15
# test: PKC and pjnk given pakts473 -> pval=2.4708259455750306e-15
# test: PKC and pjnk given PKA -> pval=2.8132731443906727e-15
# test: PKC and pjnk given P38 -> pval=1.3304134380434706e-17
# test: P38 and PKC given praf -> pval=2.6185896983736446e-115
# test: P38 and PKC given pmek -> pval=2.1588290151151913e-115
# test: P38 and PKC given plcg -> pval=1.160328666131391e-115
# test: P38 and PKC given PIP2 -> pval=9.032513066953797e-116
# test: P38 and PKC given PIP3 -> pval=1.183074250241154e-115
# test: P38 and PKC given perk -> pval=5.89057289556949e-116
# test: P38 and PKC given pakts473 -> pval=9.048299433455144e-116
# test: P38 and PKC given PKA -> pval=1.639552393258639e-115
# test: P38 and PKC given pjnk -> pval=7.581133801136407e-118
# test: P38 and pjnk given praf -> pval=0.015471953773658533
# test: P38 and pjnk given pmek -> pval=0.01219531985034964
# test: P38 and pjnk given plcg -> pval=0.014207788113187552
# test: P38 and pjnk given PIP2 -> pval=0.014284551345667734
# test: P38 and pjnk given PIP3 -> pval=0.014200486159329595
# test: P38 and pjnk given perk -> pval=0.013385531176850027
# test: P38 and pjnk given pakts473 -> pval=0.014303762831292359
# test: P38 and pjnk given PKA -> pval=0.015320512983610653
# test: P38 and pjnk given PKC -> pval=5.974222979861056e-05
# test: pjnk and plcg given praf -> pval=0.08403978095703178
# test: pjnk and plcg given pmek -> pval=0.07998930143328795
# test: pjnk and plcg given PIP2 -> pval=0.08408776650246755
# test: pjnk and plcg given PIP3 -> pval=0.09690573141277112
# test: pjnk and plcg given perk -> pval=0.07571167455199723
# test: pjnk and plcg given pakts473 -> pval=0.07925198567886464
# test: pjnk and plcg given PKA -> pval=0.0843120687342488
# test: pjnk and plcg given PKC -> pval=0.086074787011674
# test: pjnk and plcg given P38 -> pval=0.08122603934659402
# test: pjnk and PKC given praf -> pval=2.5581086032174886e-15
# test: pjnk and PKC given pmek -> pval=1.3175122249405834e-15
# test: pjnk and PKC given plcg -> pval=2.3392031949957236e-15
# test: pjnk and PKC given PIP2 -> pval=2.294816634989377e-15
# test: pjnk and PKC given PIP3 -> pval=2.009010007821291e-15
# test: pjnk and PKC given perk -> pval=2.4767006990247617e-15
# test: pjnk and PKC given pakts473 -> pval=2.4708259455750306e-15
# test: pjnk and PKC given PKA -> pval=2.8132731443906727e-15
# test: pjnk and PKC given P38 -> pval=1.3304134380434706e-17
# test: pjnk and P38 given praf -> pval=0.015471953773658533
# test: pjnk and P38 given pmek -> pval=0.01219531985034964
# test: pjnk and P38 given plcg -> pval=0.014207788113187552
# test: pjnk and P38 given PIP2 -> pval=0.014284551345667734
# test: pjnk and P38 given PIP3 -> pval=0.014200486159329595
# test: pjnk and P38 given perk -> pval=0.013385531176850027
# test: pjnk and P38 given pakts473 -> pval=0.014303762831292359
# test: pjnk and P38 given PKA -> pval=0.015320512983610653
# test: pjnk and P38 given PKC -> pval=5.974222979861056e-05
# test: praf and pmek given plcg, PIP2 -> pval=6.632766621550825e-129
# test: praf and pmek given plcg, PIP3 -> pval=1.4462284737741366e-128
# test: praf and pmek given plcg, perk -> pval=6.234721562376984e-129
# test: praf and pmek given plcg, pakts473 -> pval=1.218913722796452e-128
# test: praf and pmek given plcg, PKA -> pval=1.236146181691548e-128
# test: praf and pmek given plcg, PKC -> pval=2.2504997345939441e-128
# test: praf and pmek given plcg, P38 -> pval=2.701754764642816e-128
# test: praf and pmek given plcg, pjnk -> pval=2.0115223508748575e-129
# test: praf and pmek given PIP2, PIP3 -> pval=1.1757500948819612e-128
# test: praf and pmek given PIP2, perk -> pval=3.811489396659149e-129
# test: praf and pmek given PIP2, pakts473 -> pval=7.093071009231658e-129
# test: praf and pmek given PIP2, PKA -> pval=7.05196353801012e-129
# test: praf and pmek given PIP2, PKC -> pval=1.2752411318632066e-128
# test: praf and pmek given PIP2, P38 -> pval=1.559335068731476e-128
# test: praf and pmek given PIP2, pjnk -> pval=1.0719311056490034e-129
# test: praf and pmek given PIP3, perk -> pval=8.031483222760094e-129
# test: praf and pmek given PIP3, pakts473 -> pval=1.523695211964875e-128
# test: praf and pmek given PIP3, PKA -> pval=1.6448941871249047e-128
# test: praf and pmek given PIP3, PKC -> pval=3.0789197177008995e-128
# test: praf and pmek given PIP3, P38 -> pval=3.6375280926347177e-128
# test: praf and pmek given PIP3, pjnk -> pval=2.4273386618029472e-129
# test: praf and pmek given perk, pakts473 -> pval=1.2081193769397653e-128
# test: praf and pmek given perk, PKA -> pval=5.452827633797465e-129
# test: praf and pmek given perk, PKC -> pval=1.1656971487813864e-128
# test: praf and pmek given perk, P38 -> pval=1.371709589653156e-128
# test: praf and pmek given perk, pjnk -> pval=1.0559786055192567e-129
# test: praf and pmek given pakts473, PKA -> pval=1.1342472624875043e-128
# test: praf and pmek given pakts473, PKC -> pval=2.1970801677018728e-128
# test: praf and pmek given pakts473, P38 -> pval=2.671172793020926e-128
# test: praf and pmek given pakts473, pjnk -> pval=1.946724265523773e-129
# test: praf and pmek given PKA, PKC -> pval=2.2573534769460187e-128
# test: praf and pmek given PKA, P38 -> pval=2.6970854198707235e-128
# test: praf and pmek given PKA, pjnk -> pval=1.9041875076339264e-129
# test: praf and pmek given PKC, P38 -> pval=2.7054968097813103e-128
# test: praf and pmek given PKC, pjnk -> pval=3.729754072302443e-129
# test: praf and pmek given P38, pjnk -> pval=4.6652754525267076e-129
# test: pmek and praf given plcg, PIP2 -> pval=6.632766621550825e-129
# test: pmek and praf given plcg, PIP3 -> pval=1.4462284737741366e-128
# test: pmek and praf given plcg, perk -> pval=6.234721562376984e-129
# test: pmek and praf given plcg, pakts473 -> pval=1.218913722796452e-128
# test: pmek and praf given plcg, PKA -> pval=1.236146181691548e-128
# test: pmek and praf given plcg, PKC -> pval=2.2504997345939441e-128
# test: pmek and praf given plcg, P38 -> pval=2.701754764642816e-128
# test: pmek and praf given plcg, pjnk -> pval=2.0115223508748575e-129
# test: pmek and praf given PIP2, PIP3 -> pval=1.1757500948819612e-128
# test: pmek and praf given PIP2, perk -> pval=3.811489396659149e-129
# test: pmek and praf given PIP2, pakts473 -> pval=7.093071009231658e-129
# test: pmek and praf given PIP2, PKA -> pval=7.05196353801012e-129
# test: pmek and praf given PIP2, PKC -> pval=1.2752411318632066e-128
# test: pmek and praf given PIP2, P38 -> pval=1.559335068731476e-128
# test: pmek and praf given PIP2, pjnk -> pval=1.0719311056490034e-129
# test: pmek and praf given PIP3, perk -> pval=8.031483222760094e-129
# test: pmek and praf given PIP3, pakts473 -> pval=1.523695211964875e-128
# test: pmek and praf given PIP3, PKA -> pval=1.6448941871249047e-128
# test: pmek and praf given PIP3, PKC -> pval=3.0789197177008995e-128
# test: pmek and praf given PIP3, P38 -> pval=3.6375280926347177e-128
# test: pmek and praf given PIP3, pjnk -> pval=2.4273386618029472e-129
# test: pmek and praf given perk, pakts473 -> pval=1.2081193769397653e-128
# test: pmek and praf given perk, PKA -> pval=5.452827633797465e-129
# test: pmek and praf given perk, PKC -> pval=1.1656971487813864e-128
# test: pmek and praf given perk, P38 -> pval=1.371709589653156e-128
# test: pmek and praf given perk, pjnk -> pval=1.0559786055192567e-129
# test: pmek and praf given pakts473, PKA -> pval=1.1342472624875043e-128
# test: pmek and praf given pakts473, PKC -> pval=2.1970801677018728e-128
# test: pmek and praf given pakts473, P38 -> pval=2.671172793020926e-128
# test: pmek and praf given pakts473, pjnk -> pval=1.946724265523773e-129
# test: pmek and praf given PKA, PKC -> pval=2.2573534769460187e-128
# test: pmek and praf given PKA, P38 -> pval=2.6970854198707235e-128
# test: pmek and praf given PKA, pjnk -> pval=1.9041875076339264e-129
# test: pmek and praf given PKC, P38 -> pval=2.7054968097813103e-128
# test: pmek and praf given PKC, pjnk -> pval=3.729754072302443e-129
# test: pmek and praf given P38, pjnk -> pval=4.6652754525267076e-129
# test: pmek and PIP3 given praf, plcg -> pval=0.05893710159791701
# test: pmek and PIP3 given praf, PIP2 -> pval=0.17645935515445144
# test: pmek and PIP3 given praf, perk -> pval=0.05894114757767714
# test: pmek and PIP3 given praf, pakts473 -> pval=0.06352729405348774
# test: pmek and PIP3 given praf, PKA -> pval=0.06622338078269427
# test: pmek and PIP3 given praf, PKC -> pval=0.06526365879278251
# test: pmek and PIP3 given praf, P38 -> pval=0.06613270672261672
# test: pmek and PIP3 given praf, pjnk -> pval=0.05773972916669638
# test: pmek and PIP3 given plcg, PIP2 -> pval=0.09351420938665583
# test: pmek and PIP3 given plcg, perk -> pval=0.04615891590275797
# test: pmek and PIP3 given plcg, pakts473 -> pval=0.05093478116293669
# test: pmek and PIP3 given plcg, PKA -> pval=0.049092756929975105
# test: pmek and PIP3 given plcg, PKC -> pval=0.04682751141958489
# test: pmek and PIP3 given plcg, P38 -> pval=0.048309298940437596
# test: pmek and PIP3 given plcg, pjnk -> pval=0.04653979109682561
# test: pmek and PIP3 given PIP2, perk -> pval=0.08599456589284789
# test: pmek and PIP3 given PIP2, pakts473 -> pval=0.09581389389084656
# test: pmek and PIP3 given PIP2, PKA -> pval=0.09259124817537061
# test: pmek and PIP3 given PIP2, PKC -> pval=0.08686014505365479
# test: pmek and PIP3 given PIP2, P38 -> pval=0.09154278729310109
# test: pmek and PIP3 given PIP2, pjnk -> pval=0.08636461045051223
# test: pmek and PIP3 given perk, pakts473 -> pval=0.04717881779690916
# test: pmek and PIP3 given perk, PKA -> pval=0.044225086394021416
# test: pmek and PIP3 given perk, PKC -> pval=0.042805412921179446
# test: pmek and PIP3 given perk, P38 -> pval=0.04422643469455473
# test: pmek and PIP3 given perk, pjnk -> pval=0.041696634422134844
# test: pmek and PIP3 given pakts473, PKA -> pval=0.04898856321073305
# test: pmek and PIP3 given pakts473, PKC -> pval=0.0467839262124666
# test: pmek and PIP3 given pakts473, P38 -> pval=0.048202573698243927
# test: pmek and PIP3 given pakts473, pjnk -> pval=0.04546099324749819
# test: pmek and PIP3 given PKA, PKC -> pval=0.0453889331792457
# test: pmek and PIP3 given PKA, P38 -> pval=0.0466387111599967
# test: pmek and PIP3 given PKA, pjnk -> pval=0.04387501367996404
# test: pmek and PIP3 given PKC, P38 -> pval=0.045849662913604955
# test: pmek and PIP3 given PKC, pjnk -> pval=0.0401552106291422
# test: pmek and PIP3 given P38, pjnk -> pval=0.04278538793524654
# test: plcg and PIP3 given praf, pmek -> pval=0.00010739130202985259
# test: plcg and PIP3 given praf, PIP2 -> pval=0.0015663505512829624
# test: plcg and PIP3 given praf, perk -> pval=9.882212998471266e-05
# test: plcg and PIP3 given praf, pakts473 -> pval=0.00010260658613426717
# test: plcg and PIP3 given praf, PKA -> pval=0.00011876788901072065
# test: plcg and PIP3 given praf, PKC -> pval=0.00011638918643506892
# test: plcg and PIP3 given praf, P38 -> pval=0.00011898261530925265
# test: plcg and PIP3 given praf, pjnk -> pval=0.00013632385860252075
# test: plcg and PIP3 given pmek, PIP2 -> pval=0.0014836911622496372
# test: plcg and PIP3 given pmek, perk -> pval=9.41773206607921e-05
# test: plcg and PIP3 given pmek, pakts473 -> pval=9.869586218354545e-05
# test: plcg and PIP3 given pmek, PKA -> pval=0.00011397256272798961
# test: plcg and PIP3 given pmek, PKC -> pval=0.00011138503082068814
# test: plcg and PIP3 given pmek, P38 -> pval=0.00011415464465755452
# test: plcg and PIP3 given pmek, pjnk -> pval=0.00013435222404391503
# test: plcg and PIP3 given PIP2, perk -> pval=0.0011823641440543385
# test: plcg and PIP3 given PIP2, pakts473 -> pval=0.0012648903246860106
# test: plcg and PIP3 given PIP2, PKA -> pval=0.001489082548927897
# test: plcg and PIP3 given PIP2, PKC -> pval=0.0014289520396061602
# test: plcg and PIP3 given PIP2, P38 -> pval=0.0014657692042448337
# test: plcg and PIP3 given PIP2, pjnk -> pval=0.0016487368251899093
# test: plcg and PIP3 given perk, pakts473 -> pval=9.296414922946573e-05
# test: plcg and PIP3 given perk, PKA -> pval=8.649343925157138e-05
# test: plcg and PIP3 given perk, PKC -> pval=8.960714834075066e-05
# test: plcg and PIP3 given perk, P38 -> pval=9.179597779006263e-05
# test: plcg and PIP3 given perk, pjnk -> pval=0.00010520356641482437
# test: plcg and PIP3 given pakts473, PKA -> pval=8.857434829240816e-05
# test: plcg and PIP3 given pakts473, PKC -> pval=9.30106640789513e-05
# test: plcg and PIP3 given pakts473, P38 -> pval=9.532356910421664e-05
# test: plcg and PIP3 given pakts473, pjnk -> pval=0.00010950065816640066
# test: plcg and PIP3 given PKA, PKC -> pval=0.0001082563400265008
# test: plcg and PIP3 given PKA, P38 -> pval=0.00011048231806514385
# test: plcg and PIP3 given PKA, pjnk -> pval=0.0001272106895631516
# test: plcg and PIP3 given PKC, P38 -> pval=0.00010725620446977697
# test: plcg and PIP3 given PKC, pjnk -> pval=0.00012875049955702412
# test: plcg and PIP3 given P38, pjnk -> pval=0.0001278712617326144
# test: plcg and pjnk given praf, pmek -> pval=0.08708071451958484
# test: plcg and pjnk given praf, PIP2 -> pval=0.08625766697266639
# test: plcg and pjnk given praf, PIP3 -> pval=0.0988142694391676
# test: plcg and pjnk given praf, perk -> pval=0.07770593975457468
# test: plcg and pjnk given praf, pakts473 -> pval=0.08133752220464519
# test: plcg and pjnk given praf, PKA -> pval=0.08648403920615277
# test: plcg and pjnk given praf, PKC -> pval=0.08703411765277892
# test: plcg and pjnk given praf, P38 -> pval=0.08284345948418238
# test: plcg and pjnk given pmek, PIP2 -> pval=0.08281936138057817
# test: plcg and pjnk given pmek, PIP3 -> pval=0.0969301640305726
# test: plcg and pjnk given pmek, perk -> pval=0.07407853211219026
# test: plcg and pjnk given pmek, pakts473 -> pval=0.07729008215099886
# test: plcg and pjnk given pmek, PKA -> pval=0.08235244956491562
# test: plcg and pjnk given pmek, PKC -> pval=0.08345250037677143
# test: plcg and pjnk given pmek, P38 -> pval=0.07911148759840246
# test: plcg and pjnk given PIP2, PIP3 -> pval=0.09639021351306092
# test: plcg and pjnk given PIP2, perk -> pval=0.07825994180070969
# test: plcg and pjnk given PIP2, pakts473 -> pval=0.08149240254824532
# test: plcg and pjnk given PIP2, PKA -> pval=0.08693222937990265
# test: plcg and pjnk given PIP2, PKC -> pval=0.08611231991725603
# test: plcg and pjnk given PIP2, P38 -> pval=0.0836495915753773
# test: plcg and pjnk given PIP3, perk -> pval=0.08894129630992581
# test: plcg and pjnk given PIP3, pakts473 -> pval=0.09335689611919419
# test: plcg and pjnk given PIP3, PKA -> pval=0.09967586702457544
# test: plcg and pjnk given PIP3, PKC -> pval=0.1057342711114322
# test: plcg and pjnk given PIP3, P38 -> pval=0.09643954500944588
# test: plcg and pjnk given perk, pakts473 -> pval=0.07498058963389415
# test: plcg and pjnk given perk, PKA -> pval=0.0788099936687241
# test: plcg and pjnk given perk, PKC -> pval=0.08024614774480218
# test: plcg and pjnk given perk, P38 -> pval=0.07470216846318804
# test: plcg and pjnk given pakts473, PKA -> pval=0.0830706303551661
# test: plcg and pjnk given pakts473, PKC -> pval=0.08424264834137742
# test: plcg and pjnk given pakts473, P38 -> pval=0.07856527846161977
# test: plcg and pjnk given PKA, PKC -> pval=0.0878960943086087
# test: plcg and pjnk given PKA, P38 -> pval=0.08347088134637054
# test: plcg and pjnk given PKC, P38 -> pval=0.09022878749448678
# test: PIP2 and PIP3 given praf, pmek -> pval=1.5890937542645538e-30
# test: PIP2 and PIP3 given praf, plcg -> pval=8.225282765251963e-30
# test: PIP2 and PIP3 given praf, perk -> pval=3.3593775323612898e-31
# test: PIP2 and PIP3 given praf, pakts473 -> pval=5.040773652821406e-31
# test: PIP2 and PIP3 given praf, PKA -> pval=6.948350708363765e-31
# test: PIP2 and PIP3 given praf, PKC -> pval=6.220656337678475e-31
# test: PIP2 and PIP3 given praf, P38 -> pval=7.363261581464061e-31
# test: PIP2 and PIP3 given praf, pjnk -> pval=7.43393955168875e-31
# test: PIP2 and PIP3 given pmek, plcg -> pval=1.5067195907009924e-29
# test: PIP2 and PIP3 given pmek, perk -> pval=6.1042912336820775e-31
# test: PIP2 and PIP3 given pmek, pakts473 -> pval=9.258831813312627e-31
# test: PIP2 and PIP3 given pmek, PKA -> pval=1.2910205468819481e-30
# test: PIP2 and PIP3 given pmek, PKC -> pval=1.154953639464648e-30
# test: PIP2 and PIP3 given pmek, P38 -> pval=1.3701535604909043e-30
# test: PIP2 and PIP3 given pmek, pjnk -> pval=1.3939707265476663e-30
# test: PIP2 and PIP3 given plcg, perk -> pval=3.944874668373286e-30
# test: PIP2 and PIP3 given plcg, pakts473 -> pval=6.0677202570155475e-30
# test: PIP2 and PIP3 given plcg, PKA -> pval=8.55762262970357e-30
# test: PIP2 and PIP3 given plcg, PKC -> pval=7.620259540965768e-30
# test: PIP2 and PIP3 given plcg, P38 -> pval=8.897432596418416e-30
# test: PIP2 and PIP3 given plcg, pjnk -> pval=8.785099694008092e-30
# test: PIP2 and PIP3 given perk, pakts473 -> pval=3.862268874533058e-31
# test: PIP2 and PIP3 given perk, PKA -> pval=3.706142091889079e-31
# test: PIP2 and PIP3 given perk, PKC -> pval=3.028925709958745e-31
# test: PIP2 and PIP3 given perk, P38 -> pval=3.5656824964032815e-31
# test: PIP2 and PIP3 given perk, pjnk -> pval=3.6587538486582076e-31
# test: PIP2 and PIP3 given pakts473, PKA -> pval=5.828359188431303e-31
# test: PIP2 and PIP3 given pakts473, PKC -> pval=4.5310496854062916e-31
# test: PIP2 and PIP3 given pakts473, P38 -> pval=5.349047503678696e-31
# test: PIP2 and PIP3 given pakts473, pjnk -> pval=5.4360248212307695e-31
# test: PIP2 and PIP3 given PKA, PKC -> pval=6.356341394488918e-31
# test: PIP2 and PIP3 given PKA, P38 -> pval=7.454696699983778e-31
# test: PIP2 and PIP3 given PKA, pjnk -> pval=7.607913430901731e-31
# test: PIP2 and PIP3 given PKC, P38 -> pval=5.874854521013532e-31
# test: PIP2 and PIP3 given PKC, pjnk -> pval=6.47268789593936e-31
# test: PIP2 and PIP3 given P38, pjnk -> pval=8.017649512172894e-31
# test: PIP3 and pmek given praf, plcg -> pval=0.05893710159791701
# test: PIP3 and pmek given praf, PIP2 -> pval=0.17645935515445144
# test: PIP3 and pmek given praf, perk -> pval=0.05894114757767714
# test: PIP3 and pmek given praf, pakts473 -> pval=0.06352729405348774
# test: PIP3 and pmek given praf, PKA -> pval=0.06622338078269427
# test: PIP3 and pmek given praf, PKC -> pval=0.06526365879278251
# test: PIP3 and pmek given praf, P38 -> pval=0.06613270672261672
# test: PIP3 and pmek given praf, pjnk -> pval=0.05773972916669638
# test: PIP3 and pmek given plcg, PIP2 -> pval=0.09351420938665583
# test: PIP3 and pmek given plcg, perk -> pval=0.04615891590275797
# test: PIP3 and pmek given plcg, pakts473 -> pval=0.05093478116293669
# test: PIP3 and pmek given plcg, PKA -> pval=0.049092756929975105
# test: PIP3 and pmek given plcg, PKC -> pval=0.04682751141958489
# test: PIP3 and pmek given plcg, P38 -> pval=0.048309298940437596
# test: PIP3 and pmek given plcg, pjnk -> pval=0.04653979109682561
# test: PIP3 and pmek given PIP2, perk -> pval=0.08599456589284789
# test: PIP3 and pmek given PIP2, pakts473 -> pval=0.09581389389084656
# test: PIP3 and pmek given PIP2, PKA -> pval=0.09259124817537061
# test: PIP3 and pmek given PIP2, PKC -> pval=0.08686014505365479
# test: PIP3 and pmek given PIP2, P38 -> pval=0.09154278729310109
# test: PIP3 and pmek given PIP2, pjnk -> pval=0.08636461045051223
# test: PIP3 and pmek given perk, pakts473 -> pval=0.04717881779690916
# test: PIP3 and pmek given perk, PKA -> pval=0.044225086394021416
# test: PIP3 and pmek given perk, PKC -> pval=0.042805412921179446
# test: PIP3 and pmek given perk, P38 -> pval=0.04422643469455473
# test: PIP3 and pmek given perk, pjnk -> pval=0.041696634422134844
# test: PIP3 and pmek given pakts473, PKA -> pval=0.04898856321073305
# test: PIP3 and pmek given pakts473, PKC -> pval=0.0467839262124666
# test: PIP3 and pmek given pakts473, P38 -> pval=0.048202573698243927
# test: PIP3 and pmek given pakts473, pjnk -> pval=0.04546099324749819
# test: PIP3 and pmek given PKA, PKC -> pval=0.0453889331792457
# test: PIP3 and pmek given PKA, P38 -> pval=0.0466387111599967
# test: PIP3 and pmek given PKA, pjnk -> pval=0.04387501367996404
# test: PIP3 and pmek given PKC, P38 -> pval=0.045849662913604955
# test: PIP3 and pmek given PKC, pjnk -> pval=0.0401552106291422
# test: PIP3 and pmek given P38, pjnk -> pval=0.04278538793524654
# test: PIP3 and plcg given praf, pmek -> pval=0.00010739130202985259
# test: PIP3 and plcg given praf, PIP2 -> pval=0.0015663505512829624
# test: PIP3 and plcg given praf, perk -> pval=9.882212998471266e-05
# test: PIP3 and plcg given praf, pakts473 -> pval=0.00010260658613426717
# test: PIP3 and plcg given praf, PKA -> pval=0.00011876788901072065
# test: PIP3 and plcg given praf, PKC -> pval=0.00011638918643506892
# test: PIP3 and plcg given praf, P38 -> pval=0.00011898261530925265
# test: PIP3 and plcg given praf, pjnk -> pval=0.00013632385860252075
# test: PIP3 and plcg given pmek, PIP2 -> pval=0.0014836911622496372
# test: PIP3 and plcg given pmek, perk -> pval=9.41773206607921e-05
# test: PIP3 and plcg given pmek, pakts473 -> pval=9.869586218354545e-05
# test: PIP3 and plcg given pmek, PKA -> pval=0.00011397256272798961
# test: PIP3 and plcg given pmek, PKC -> pval=0.00011138503082068814
# test: PIP3 and plcg given pmek, P38 -> pval=0.00011415464465755452
# test: PIP3 and plcg given pmek, pjnk -> pval=0.00013435222404391503
# test: PIP3 and plcg given PIP2, perk -> pval=0.0011823641440543385
# test: PIP3 and plcg given PIP2, pakts473 -> pval=0.0012648903246860106
# test: PIP3 and plcg given PIP2, PKA -> pval=0.001489082548927897
# test: PIP3 and plcg given PIP2, PKC -> pval=0.0014289520396061602
# test: PIP3 and plcg given PIP2, P38 -> pval=0.0014657692042448337
# test: PIP3 and plcg given PIP2, pjnk -> pval=0.0016487368251899093
# test: PIP3 and plcg given perk, pakts473 -> pval=9.296414922946573e-05
# test: PIP3 and plcg given perk, PKA -> pval=8.649343925157138e-05
# test: PIP3 and plcg given perk, PKC -> pval=8.960714834075066e-05
# test: PIP3 and plcg given perk, P38 -> pval=9.179597779006263e-05
# test: PIP3 and plcg given perk, pjnk -> pval=0.00010520356641482437
# test: PIP3 and plcg given pakts473, PKA -> pval=8.857434829240816e-05
# test: PIP3 and plcg given pakts473, PKC -> pval=9.30106640789513e-05
# test: PIP3 and plcg given pakts473, P38 -> pval=9.532356910421664e-05
# test: PIP3 and plcg given pakts473, pjnk -> pval=0.00010950065816640066
# test: PIP3 and plcg given PKA, PKC -> pval=0.0001082563400265008
# test: PIP3 and plcg given PKA, P38 -> pval=0.00011048231806514385
# test: PIP3 and plcg given PKA, pjnk -> pval=0.0001272106895631516
# test: PIP3 and plcg given PKC, P38 -> pval=0.00010725620446977697
# test: PIP3 and plcg given PKC, pjnk -> pval=0.00012875049955702412
# test: PIP3 and plcg given P38, pjnk -> pval=0.0001278712617326144
# test: PIP3 and PIP2 given praf, pmek -> pval=1.5890937542645538e-30
# test: PIP3 and PIP2 given praf, plcg -> pval=8.225282765251963e-30
# test: PIP3 and PIP2 given praf, perk -> pval=3.3593775323612898e-31
# test: PIP3 and PIP2 given praf, pakts473 -> pval=5.040773652821406e-31
# test: PIP3 and PIP2 given praf, PKA -> pval=6.948350708363765e-31
# test: PIP3 and PIP2 given praf, PKC -> pval=6.220656337678475e-31
# test: PIP3 and PIP2 given praf, P38 -> pval=7.363261581464061e-31
# test: PIP3 and PIP2 given praf, pjnk -> pval=7.43393955168875e-31
# test: PIP3 and PIP2 given pmek, plcg -> pval=1.5067195907009924e-29
# test: PIP3 and PIP2 given pmek, perk -> pval=6.1042912336820775e-31
# test: PIP3 and PIP2 given pmek, pakts473 -> pval=9.258831813312627e-31
# test: PIP3 and PIP2 given pmek, PKA -> pval=1.2910205468819481e-30
# test: PIP3 and PIP2 given pmek, PKC -> pval=1.154953639464648e-30
# test: PIP3 and PIP2 given pmek, P38 -> pval=1.3701535604909043e-30
# test: PIP3 and PIP2 given pmek, pjnk -> pval=1.3939707265476663e-30
# test: PIP3 and PIP2 given plcg, perk -> pval=3.944874668373286e-30
# test: PIP3 and PIP2 given plcg, pakts473 -> pval=6.0677202570155475e-30
# test: PIP3 and PIP2 given plcg, PKA -> pval=8.55762262970357e-30
# test: PIP3 and PIP2 given plcg, PKC -> pval=7.620259540965768e-30
# test: PIP3 and PIP2 given plcg, P38 -> pval=8.897432596418416e-30
# test: PIP3 and PIP2 given plcg, pjnk -> pval=8.785099694008092e-30
# test: PIP3 and PIP2 given perk, pakts473 -> pval=3.862268874533058e-31
# test: PIP3 and PIP2 given perk, PKA -> pval=3.706142091889079e-31
# test: PIP3 and PIP2 given perk, PKC -> pval=3.028925709958745e-31
# test: PIP3 and PIP2 given perk, P38 -> pval=3.5656824964032815e-31
# test: PIP3 and PIP2 given perk, pjnk -> pval=3.6587538486582076e-31
# test: PIP3 and PIP2 given pakts473, PKA -> pval=5.828359188431303e-31
# test: PIP3 and PIP2 given pakts473, PKC -> pval=4.5310496854062916e-31
# test: PIP3 and PIP2 given pakts473, P38 -> pval=5.349047503678696e-31
# test: PIP3 and PIP2 given pakts473, pjnk -> pval=5.4360248212307695e-31
# test: PIP3 and PIP2 given PKA, PKC -> pval=6.356341394488918e-31
# test: PIP3 and PIP2 given PKA, P38 -> pval=7.454696699983778e-31
# test: PIP3 and PIP2 given PKA, pjnk -> pval=7.607913430901731e-31
# test: PIP3 and PIP2 given PKC, P38 -> pval=5.874854521013532e-31
# test: PIP3 and PIP2 given PKC, pjnk -> pval=6.47268789593936e-31
# test: PIP3 and PIP2 given P38, pjnk -> pval=8.017649512172894e-31
# test: perk and pakts473 given praf, pmek -> pval=2.4690380936492594e-264
# test: perk and pakts473 given praf, plcg -> pval=8.045645782339138e-264
# test: perk and pakts473 given praf, PIP2 -> pval=3.8159057280011783e-264
# test: perk and pakts473 given praf, PIP3 -> pval=1.0684742446118757e-263
# test: perk and pakts473 given praf, PKA -> pval=3.993620085656822e-239
# test: perk and pakts473 given praf, PKC -> pval=6.370656951580089e-264
# test: perk and pakts473 given praf, P38 -> pval=3.4405359928439714e-264
# test: perk and pakts473 given praf, pjnk -> pval=5.830431323100903e-264
# test: perk and pakts473 given pmek, plcg -> pval=1.988287518531068e-264
# test: perk and pakts473 given pmek, PIP2 -> pval=1.031050767645432e-264
# test: perk and pakts473 given pmek, PIP3 -> pval=2.7875385273076925e-264
# test: perk and pakts473 given pmek, PKA -> pval=1.0642679499031593e-239
# test: perk and pakts473 given pmek, PKC -> pval=1.65736582223367e-264
# test: perk and pakts473 given pmek, P38 -> pval=8.715587578129012e-265
# test: perk and pakts473 given pmek, pjnk -> pval=1.5773939364638984e-264
# test: perk and pakts473 given plcg, PIP2 -> pval=5.8136965237438205e-264
# test: perk and pakts473 given plcg, PIP3 -> pval=1.9608488330808564e-263
# test: perk and pakts473 given plcg, PKA -> pval=8.163942608533584e-239
# test: perk and pakts473 given plcg, PKC -> pval=9.897589797666123e-264
# test: perk and pakts473 given plcg, P38 -> pval=4.929816937316721e-264
# test: perk and pakts473 given plcg, pjnk -> pval=9.36904229485802e-264
# test: perk and pakts473 given PIP2, PIP3 -> pval=1.294209623777731e-263
# test: perk and pakts473 given PIP2, PKA -> pval=2.3459189626527297e-239
# test: perk and pakts473 given PIP2, PKC -> pval=4.851817393841166e-264
# test: perk and pakts473 given PIP2, P38 -> pval=2.3638807564329007e-264
# test: perk and pakts473 given PIP2, pjnk -> pval=4.437475679401587e-264
# test: perk and pakts473 given PIP3, PKA -> pval=9.374052826399641e-239
# test: perk and pakts473 given PIP3, PKC -> pval=1.3757103484483479e-263
# test: perk and pakts473 given PIP3, P38 -> pval=6.837261563506732e-264
# test: perk and pakts473 given PIP3, pjnk -> pval=1.250441746224214e-263
# test: perk and pakts473 given PKA, PKC -> pval=4.469538830442215e-239
# test: perk and pakts473 given PKA, P38 -> pval=3.463486181761412e-239
# test: perk and pakts473 given PKA, pjnk -> pval=3.5584212966937775e-239
# test: perk and pakts473 given PKC, P38 -> pval=6.721501405019631e-264
# test: perk and pakts473 given PKC, pjnk -> pval=5.8568729406036165e-264
# test: perk and pakts473 given P38, pjnk -> pval=3.5261976653402035e-264
# test: pakts473 and perk given praf, pmek -> pval=2.4690380936492594e-264
# test: pakts473 and perk given praf, plcg -> pval=8.045645782339138e-264
# test: pakts473 and perk given praf, PIP2 -> pval=3.8159057280011783e-264
# test: pakts473 and perk given praf, PIP3 -> pval=1.0684742446118757e-263
# test: pakts473 and perk given praf, PKA -> pval=3.993620085656822e-239
# test: pakts473 and perk given praf, PKC -> pval=6.370656951580089e-264
# test: pakts473 and perk given praf, P38 -> pval=3.4405359928439714e-264
# test: pakts473 and perk given praf, pjnk -> pval=5.830431323100903e-264
# test: pakts473 and perk given pmek, plcg -> pval=1.988287518531068e-264
# test: pakts473 and perk given pmek, PIP2 -> pval=1.031050767645432e-264
# test: pakts473 and perk given pmek, PIP3 -> pval=2.7875385273076925e-264
# test: pakts473 and perk given pmek, PKA -> pval=1.0642679499031593e-239
# test: pakts473 and perk given pmek, PKC -> pval=1.65736582223367e-264
# test: pakts473 and perk given pmek, P38 -> pval=8.715587578129012e-265
# test: pakts473 and perk given pmek, pjnk -> pval=1.5773939364638984e-264
# test: pakts473 and perk given plcg, PIP2 -> pval=5.8136965237438205e-264
# test: pakts473 and perk given plcg, PIP3 -> pval=1.9608488330808564e-263
# test: pakts473 and perk given plcg, PKA -> pval=8.163942608533584e-239
# test: pakts473 and perk given plcg, PKC -> pval=9.897589797666123e-264
# test: pakts473 and perk given plcg, P38 -> pval=4.929816937316721e-264
# test: pakts473 and perk given plcg, pjnk -> pval=9.36904229485802e-264
# test: pakts473 and perk given PIP2, PIP3 -> pval=1.294209623777731e-263
# test: pakts473 and perk given PIP2, PKA -> pval=2.3459189626527297e-239
# test: pakts473 and perk given PIP2, PKC -> pval=4.851817393841166e-264
# test: pakts473 and perk given PIP2, P38 -> pval=2.3638807564329007e-264
# test: pakts473 and perk given PIP2, pjnk -> pval=4.437475679401587e-264
# test: pakts473 and perk given PIP3, PKA -> pval=9.374052826399641e-239
# test: pakts473 and perk given PIP3, PKC -> pval=1.3757103484483479e-263
# test: pakts473 and perk given PIP3, P38 -> pval=6.837261563506732e-264
# test: pakts473 and perk given PIP3, pjnk -> pval=1.250441746224214e-263
# test: pakts473 and perk given PKA, PKC -> pval=4.469538830442215e-239
# test: pakts473 and perk given PKA, P38 -> pval=3.463486181761412e-239
# test: pakts473 and perk given PKA, pjnk -> pval=3.5584212966937775e-239
# test: pakts473 and perk given PKC, P38 -> pval=6.721501405019631e-264
# test: pakts473 and perk given PKC, pjnk -> pval=5.8568729406036165e-264
# test: pakts473 and perk given P38, pjnk -> pval=3.5261976653402035e-264
# test: pakts473 and PKA given praf, pmek -> pval=1.8038221184707668e-38
# test: pakts473 and PKA given praf, plcg -> pval=1.4807307106539642e-38
# test: pakts473 and PKA given praf, PIP2 -> pval=2.115324840442544e-38
# test: pakts473 and PKA given praf, PIP3 -> pval=1.6668577153499712e-38
# test: pakts473 and PKA given praf, perk -> pval=2.1116416295164295e-13
# test: pakts473 and PKA given praf, PKC -> pval=2.409358821111882e-38
# test: pakts473 and PKA given praf, P38 -> pval=1.731183342703839e-38
# test: pakts473 and PKA given praf, pjnk -> pval=2.2144213555835226e-38
# test: pakts473 and PKA given pmek, plcg -> pval=1.6465816655078657e-38
# test: pakts473 and PKA given pmek, PIP2 -> pval=2.3449700366675916e-38
# test: pakts473 and PKA given pmek, PIP3 -> pval=1.8264315638317677e-38
# test: pakts473 and PKA given pmek, perk -> pval=2.476217045245323e-13
# test: pakts473 and PKA given pmek, PKC -> pval=2.685903439002789e-38
# test: pakts473 and PKA given pmek, P38 -> pval=1.9454847981455735e-38
# test: pakts473 and PKA given pmek, pjnk -> pval=2.4779046849333074e-38
# test: pakts473 and PKA given plcg, PIP2 -> pval=1.7610037253103771e-38
# test: pakts473 and PKA given plcg, PIP3 -> pval=1.3091701350865562e-38
# test: pakts473 and PKA given plcg, perk -> pval=2.3797017150267905e-13
# test: pakts473 and PKA given plcg, PKC -> pval=2.0819918954799375e-38
# test: pakts473 and PKA given plcg, P38 -> pval=1.5020610874904354e-38
# test: pakts473 and PKA given plcg, pjnk -> pval=1.9170999623917343e-38
# test: pakts473 and PKA given PIP2, PIP3 -> pval=2.284825410568416e-38
# test: pakts473 and PKA given PIP2, perk -> pval=1.9904076740953182e-13
# test: pakts473 and PKA given PIP2, PKC -> pval=2.957344457063918e-38
# test: pakts473 and PKA given PIP2, P38 -> pval=2.1267711040957273e-38
# test: pakts473 and PKA given PIP2, pjnk -> pval=2.679640424596489e-38
# test: pakts473 and PKA given PIP3, perk -> pval=2.1763460248849685e-13
# test: pakts473 and PKA given PIP3, PKC -> pval=2.3178277838513537e-38
# test: pakts473 and PKA given PIP3, P38 -> pval=1.668507753683844e-38
# test: pakts473 and PKA given PIP3, pjnk -> pval=2.0726782113530613e-38
# test: pakts473 and PKA given perk, PKC -> pval=2.639003784370983e-13
# test: pakts473 and PKA given perk, P38 -> pval=2.955036918076669e-13
# test: pakts473 and PKA given perk, pjnk -> pval=2.0319961074670475e-13
# test: pakts473 and PKA given PKC, P38 -> pval=2.4521332974129067e-38
# test: pakts473 and PKA given PKC, pjnk -> pval=2.861424366058818e-38
# test: pakts473 and PKA given P38, pjnk -> pval=2.233532926374746e-38
# test: PKA and pakts473 given praf, pmek -> pval=1.8038221184707668e-38
# test: PKA and pakts473 given praf, plcg -> pval=1.4807307106539642e-38
# test: PKA and pakts473 given praf, PIP2 -> pval=2.115324840442544e-38
# test: PKA and pakts473 given praf, PIP3 -> pval=1.6668577153499712e-38
# test: PKA and pakts473 given praf, perk -> pval=2.1116416295164295e-13
# test: PKA and pakts473 given praf, PKC -> pval=2.409358821111882e-38
# test: PKA and pakts473 given praf, P38 -> pval=1.731183342703839e-38
# test: PKA and pakts473 given praf, pjnk -> pval=2.2144213555835226e-38
# test: PKA and pakts473 given pmek, plcg -> pval=1.6465816655078657e-38
# test: PKA and pakts473 given pmek, PIP2 -> pval=2.3449700366675916e-38
# test: PKA and pakts473 given pmek, PIP3 -> pval=1.8264315638317677e-38
# test: PKA and pakts473 given pmek, perk -> pval=2.476217045245323e-13
# test: PKA and pakts473 given pmek, PKC -> pval=2.685903439002789e-38
# test: PKA and pakts473 given pmek, P38 -> pval=1.9454847981455735e-38
# test: PKA and pakts473 given pmek, pjnk -> pval=2.4779046849333074e-38
# test: PKA and pakts473 given plcg, PIP2 -> pval=1.7610037253103771e-38
# test: PKA and pakts473 given plcg, PIP3 -> pval=1.3091701350865562e-38
# test: PKA and pakts473 given plcg, perk -> pval=2.3797017150267905e-13
# test: PKA and pakts473 given plcg, PKC -> pval=2.0819918954799375e-38
# test: PKA and pakts473 given plcg, P38 -> pval=1.5020610874904354e-38
# test: PKA and pakts473 given plcg, pjnk -> pval=1.9170999623917343e-38
# test: PKA and pakts473 given PIP2, PIP3 -> pval=2.284825410568416e-38
# test: PKA and pakts473 given PIP2, perk -> pval=1.9904076740953182e-13
# test: PKA and pakts473 given PIP2, PKC -> pval=2.957344457063918e-38
# test: PKA and pakts473 given PIP2, P38 -> pval=2.1267711040957273e-38
# test: PKA and pakts473 given PIP2, pjnk -> pval=2.679640424596489e-38
# test: PKA and pakts473 given PIP3, perk -> pval=2.1763460248849685e-13
# test: PKA and pakts473 given PIP3, PKC -> pval=2.3178277838513537e-38
# test: PKA and pakts473 given PIP3, P38 -> pval=1.668507753683844e-38
# test: PKA and pakts473 given PIP3, pjnk -> pval=2.0726782113530613e-38
# test: PKA and pakts473 given perk, PKC -> pval=2.639003784370983e-13
# test: PKA and pakts473 given perk, P38 -> pval=2.955036918076669e-13
# test: PKA and pakts473 given perk, pjnk -> pval=2.0319961074670475e-13
# test: PKA and pakts473 given PKC, P38 -> pval=2.4521332974129067e-38
# test: PKA and pakts473 given PKC, pjnk -> pval=2.861424366058818e-38
# test: PKA and pakts473 given P38, pjnk -> pval=2.233532926374746e-38
# test: PKC and P38 given praf, pmek -> pval=3.490096936669995e-115
# test: PKC and P38 given praf, plcg -> pval=3.4087671142696515e-115
# test: PKC and P38 given praf, PIP2 -> pval=2.670961350276614e-115
# test: PKC and P38 given praf, PIP3 -> pval=3.5546306508582975e-115
# test: PKC and P38 given praf, perk -> pval=1.7319282194777768e-115
# test: PKC and P38 given praf, pakts473 -> pval=2.6077256234797244e-115
# test: PKC and P38 given praf, PKA -> pval=4.842080028062612e-115
# test: PKC and P38 given praf, pjnk -> pval=2.0117792660415234e-117
# test: PKC and P38 given pmek, plcg -> pval=2.8251517740457713e-115
# ...
# test: PKC and P38 given PIP3, pakts473 -> pval=1.201288262912943e-115
# test: PKC and P38 given PIP3, PKA -> pval=2.1916383832603223e-115
# test: PKC and P38 given PIP3, pjnk -> pval=9.947260343730849e-118
# test: PKC and P38 given perk, pakts473 -> pval=1.015962589668268e-115
# test: PKC and P38 given perk, PKA -> pval=1.235526786013297e-115
# test: PKC and P38 given perk, pjnk -> pval=6.24020900595e-118
# test: PKC and P38 given pakts473, PKA -> pval=1.6677223280537929e-115
# test: PKC and P38 given pakts473, pjnk -> pval=8.088989573474496e-118
# test: PKC and P38 given PKA, pjnk -> pval=1.3196458325697809e-117
# test: PKC and pjnk given praf, pmek -> pval=1.6556983360586673e-15
# test: PKC and pjnk given praf, plcg -> pval=2.7281603466024184e-15
# test: PKC and pjnk given praf, PIP2 -> pval=2.7083119741229433e-15
# test: PKC and pjnk given praf, PIP3 -> pval=2.356264501826227e-15
# test: PKC and pjnk given praf, perk -> pval=2.9059856011046468e-15
# test: PKC and pjnk given praf, pakts473 -> pval=2.8936195783918025e-15
# test: PKC and pjnk given praf, PKA -> pval=3.3177250343163807e-15
# test: PKC and pjnk given praf, P38 -> pval=1.4071265383093388e-17
# test: PKC and pjnk given pmek, plcg -> pval=1.414813951340978e-15
# test: PKC and pjnk given pmek, PIP2 -> pval=1.4038502797431172e-15
# test: PKC and pjnk given pmek, PIP3 -> pval=1.175725385209787e-15
# test: PKC and pjnk given pmek, perk -> pval=1.5134572512639818e-15
# test: PKC and pjnk given pmek, pakts473 -> pval=1.5060544915030008e-15
# test: PKC and pjnk given pmek, PKA -> pval=1.7148166715654713e-15
# test: PKC and pjnk given pmek, P38 -> pval=1.0567732921920754e-17
# test: PKC and pjnk given plcg, PIP2 -> pval=2.4252556552902025e-15
# test: PKC and pjnk given plcg, PIP3 -> pval=2.234907348942737e-15
# test: PKC and pjnk given plcg, perk -> pval=2.692800392878482e-15
# test: PKC and pjnk given plcg, pakts473 -> pval=2.692498424234253e-15
# test: PKC and pjnk given plcg, PKA -> pval=3.016262578547631e-15
# test: PKC and pjnk given plcg, P38 -> pval=1.511767669234646e-17
# test: PKC and pjnk given PIP2, PIP3 -> pval=2.00710457435191e-15
# test: PKC and pjnk given PIP2, perk -> pval=2.638558396218044e-15
# test: PKC and pjnk given PIP2, pakts473 -> pval=2.6204340844646367e-15
# test: PKC and pjnk given PIP2, PKA -> pval=2.9909958776863177e-15
# test: PKC and pjnk given PIP2, P38 -> pval=1.4240313121916482e-17
# test: PKC and pjnk given PIP3, perk -> pval=2.3015041936184108e-15
# test: PKC and pjnk given PIP3, pakts473 -> pval=2.2834781513644723e-15
# test: PKC and pjnk given PIP3, PKA -> pval=2.6089151141679394e-15
# test: PKC and pjnk given PIP3, P38 -> pval=1.2104287087588089e-17
# test: PKC and pjnk given perk, pakts473 -> pval=2.2134524601737025e-15
# test: PKC and pjnk given perk, PKA -> pval=2.932093507838832e-15
# test: PKC and pjnk given perk, P38 -> pval=1.8822210017819683e-17
# test: PKC and pjnk given pakts473, PKA -> pval=2.957672317073945e-15
# test: PKC and pjnk given pakts473, P38 -> pval=1.5823706513341065e-17
# test: PKC and pjnk given PKA, P38 -> pval=1.6206636171887028e-17
# test: P38 and PKC given praf, pmek -> pval=3.490096936669995e-115
# test: P38 and PKC given praf, plcg -> pval=3.4087671142696515e-115
# test: P38 and PKC given praf, PIP2 -> pval=2.670961350276614e-115
# test: P38 and PKC given praf, PIP3 -> pval=3.5546306508582975e-115
# test: P38 and PKC given praf, perk -> pval=1.7319282194777768e-115
# test: P38 and PKC given praf, pakts473 -> pval=2.6077256234797244e-115
# test: P38 and PKC given praf, PKA -> pval=4.842080028062612e-115
# test: P38 and PKC given praf, pjnk -> pval=2.0117792660415234e-117
# test: P38 and PKC given pmek, plcg -> pval=2.8251517740457713e-115
# test: P38 and PKC given pmek, PIP2 -> pval=2.184360606631369e-115
# test: P38 and PKC given pmek, PIP3 -> pval=2.950855178035624e-115
# test: P38 and PKC given pmek, perk -> pval=1.4390270949355593e-115
# test: P38 and PKC given pmek, pakts473 -> pval=2.1950106890884616e-115
# test: P38 and PKC given pmek, PKA -> pval=3.978556869372042e-115
# test: P38 and PKC given pmek, pjnk -> pval=2.403813931121982e-117
# test: P38 and PKC given plcg, PIP2 -> pval=1.203980919306046e-115
# test: P38 and PKC given plcg, PIP3 -> pval=1.5378860929310437e-115
# test: P38 and PKC given plcg, perk -> pval=7.618745191646125e-116
# test: P38 and PKC given plcg, pakts473 -> pval=1.1801852463195021e-115
# test: P38 and PKC given plcg, PKA -> pval=2.1488066664124115e-115
# test: P38 and PKC given plcg, pjnk -> pval=1.046185113995207e-117
# test: P38 and PKC given PIP2, PIP3 -> pval=1.049246313072259e-115
# test: P38 and PKC given PIP2, perk -> pval=5.78921967760153e-116
# test: P38 and PKC given PIP2, pakts473 -> pval=9.151159118082067e-116
# test: P38 and PKC given PIP2, PKA -> pval=1.6689855456929598e-115
# test: P38 and PKC given PIP2, pjnk -> pval=7.825198424217668e-118
# test: P38 and PKC given PIP3, perk -> pval=7.758531823802656e-116
# test: P38 and PKC given PIP3, pakts473 -> pval=1.201288262912943e-115
# test: P38 and PKC given PIP3, PKA -> pval=2.1916383832603223e-115
# test: P38 and PKC given PIP3, pjnk -> pval=9.947260343730849e-118
# test: P38 and PKC given perk, pakts473 -> pval=1.015962589668268e-115
# test: P38 and PKC given perk, PKA -> pval=1.235526786013297e-115
# test: P38 and PKC given perk, pjnk -> pval=6.24020900595e-118
# test: P38 and PKC given pakts473, PKA -> pval=1.6677223280537929e-115
# test: P38 and PKC given pakts473, pjnk -> pval=8.088989573474496e-118
# test: P38 and PKC given PKA, pjnk -> pval=1.3196458325697809e-117
# test: P38 and pjnk given praf, pmek -> pval=0.01488630862730005
# test: P38 and pjnk given praf, plcg -> pval=0.015298583322197861
# test: P38 and pjnk given praf, PIP2 -> pval=0.015465487253469377
# test: P38 and pjnk given praf, PIP3 -> pval=0.015323807788863861
# test: P38 and pjnk given praf, perk -> pval=0.014469859129320289
# test: P38 and pjnk given praf, pakts473 -> pval=0.015441854270180048
# test: P38 and pjnk given praf, PKA -> pval=0.01657478989016558
# test: P38 and pjnk given praf, PKC -> pval=5.73927826347539e-05
# test: P38 and pjnk given pmek, plcg -> pval=0.012098310003579889
# test: P38 and pjnk given pmek, PIP2 -> pval=0.012163666942439071
# test: P38 and pjnk given pmek, PIP3 -> pval=0.012018007552021296
# test: P38 and pjnk given pmek, perk -> pval=0.01145648151047626
# test: P38 and pjnk given pmek, pakts473 -> pval=0.012194962479935378
# test: P38 and pjnk given pmek, PKA -> pval=0.013091175504861765
# test: P38 and pjnk given pmek, PKC -> pval=6.79776468940501e-05
# test: P38 and pjnk given plcg, PIP2 -> pval=0.014244885915887316
# test: P38 and pjnk given plcg, PIP3 -> pval=0.014169296577645403
# test: P38 and pjnk given plcg, perk -> pval=0.013246703896689773
# test: P38 and pjnk given plcg, pakts473 -> pval=0.014217108572180115
# test: P38 and pjnk given plcg, PKA -> pval=0.015209356234890128
# test: P38 and pjnk given plcg, PKC -> pval=6.27000094576056e-05
# test: P38 and pjnk given PIP2, PIP3 -> pval=0.014271355839549615
# test: P38 and pjnk given PIP2, perk -> pval=0.013361350722358516
# test: P38 and pjnk given PIP2, pakts473 -> pval=0.014295897201945762
# test: P38 and pjnk given PIP2, PKA -> pval=0.01531402717093976
# test: P38 and pjnk given PIP2, PKC -> pval=6.039855307374888e-05
# test: P38 and pjnk given PIP3, perk -> pval=0.01333249155913665
# test: P38 and pjnk given PIP3, pakts473 -> pval=0.01422127370587823
# test: P38 and pjnk given PIP3, PKA -> pval=0.015225485289473581
# test: P38 and pjnk given PIP3, PKC -> pval=5.822292096585139e-05
# test: P38 and pjnk given perk, pakts473 -> pval=0.012532255198454325
# test: P38 and pjnk given perk, PKA -> pval=0.014293542412760768
# test: P38 and pjnk given perk, PKC -> pval=7.024278852290253e-05
# test: P38 and pjnk given pakts473, PKA -> pval=0.015259259788695448
# test: P38 and pjnk given pakts473, PKC -> pval=6.251012143297801e-05
# test: P38 and pjnk given PKA, PKC -> pval=5.9695397479464615e-05
# test: pjnk and plcg given praf, pmek -> pval=0.08708071451958484
# test: pjnk and plcg given praf, PIP2 -> pval=0.08625766697266639
# test: pjnk and plcg given praf, PIP3 -> pval=0.0988142694391676
# test: pjnk and plcg given praf, perk -> pval=0.07770593975457468
# test: pjnk and plcg given praf, pakts473 -> pval=0.08133752220464519
# test: pjnk and plcg given praf, PKA -> pval=0.08648403920615277
# test: pjnk and plcg given praf, PKC -> pval=0.08703411765277892
# test: pjnk and plcg given praf, P38 -> pval=0.08284345948418238
# test: pjnk and plcg given pmek, PIP2 -> pval=0.08281936138057817
# test: pjnk and plcg given pmek, PIP3 -> pval=0.0969301640305726
# test: pjnk and plcg given pmek, perk -> pval=0.07407853211219026
# test: pjnk and plcg given pmek, pakts473 -> pval=0.07729008215099886
# test: pjnk and plcg given pmek, PKA -> pval=0.08235244956491562
# test: pjnk and plcg given pmek, PKC -> pval=0.08345250037677143
# test: pjnk and plcg given pmek, P38 -> pval=0.07911148759840246
# test: pjnk and plcg given PIP2, PIP3 -> pval=0.09639021351306092
# test: pjnk and plcg given PIP2, perk -> pval=0.07825994180070969
# test: pjnk and plcg given PIP2, pakts473 -> pval=0.08149240254824532
# test: pjnk and plcg given PIP2, PKA -> pval=0.08693222937990265
# test: pjnk and plcg given PIP2, PKC -> pval=0.08611231991725603
# test: pjnk and plcg given PIP2, P38 -> pval=0.0836495915753773
# test: pjnk and plcg given PIP3, perk -> pval=0.08894129630992581
# test: pjnk and plcg given PIP3, pakts473 -> pval=0.09335689611919419
# test: pjnk and plcg given PIP3, PKA -> pval=0.09967586702457544
# test: pjnk and plcg given PIP3, PKC -> pval=0.1057342711114322
# test: pjnk and plcg given PIP3, P38 -> pval=0.09643954500944588
# test: pjnk and plcg given perk, pakts473 -> pval=0.07498058963389415
# test: pjnk and plcg given perk, PKA -> pval=0.0788099936687241
# test: pjnk and plcg given perk, PKC -> pval=0.08024614774480218
# test: pjnk and plcg given perk, P38 -> pval=0.07470216846318804
# test: pjnk and plcg given pakts473, PKA -> pval=0.0830706303551661
# test: pjnk and plcg given pakts473, PKC -> pval=0.08424264834137742
# test: pjnk and plcg given pakts473, P38 -> pval=0.07856527846161977
# test: pjnk and plcg given PKA, PKC -> pval=0.0878960943086087
# test: pjnk and plcg given PKA, P38 -> pval=0.08347088134637054
# test: pjnk and plcg given PKC, P38 -> pval=0.09022878749448678
# test: pjnk and PKC given praf, pmek -> pval=1.6556983360586673e-15
# test: pjnk and PKC given praf, plcg -> pval=2.7281603466024184e-15
# test: pjnk and PKC given praf, PIP2 -> pval=2.7083119741229433e-15
# test: pjnk and PKC given praf, PIP3 -> pval=2.356264501826227e-15
# test: pjnk and PKC given praf, perk -> pval=2.9059856011046468e-15
# test: pjnk and PKC given praf, pakts473 -> pval=2.8936195783918025e-15
# test: pjnk and PKC given praf, PKA -> pval=3.3177250343163807e-15
# test: pjnk and PKC given praf, P38 -> pval=1.4071265383093388e-17
# test: pjnk and PKC given pmek, plcg -> pval=1.414813951340978e-15
# test: pjnk and PKC given pmek, PIP2 -> pval=1.4038502797431172e-15
# test: pjnk and PKC given pmek, PIP3 -> pval=1.175725385209787e-15
# test: pjnk and PKC given pmek, perk -> pval=1.5134572512639818e-15
# test: pjnk and PKC given pmek, pakts473 -> pval=1.5060544915030008e-15
# test: pjnk and PKC given pmek, PKA -> pval=1.7148166715654713e-15
# test: pjnk and PKC given pmek, P38 -> pval=1.0567732921920754e-17
# test: pjnk and PKC given plcg, PIP2 -> pval=2.4252556552902025e-15
# test: pjnk and PKC given plcg, PIP3 -> pval=2.234907348942737e-15
# test: pjnk and PKC given plcg, perk -> pval=2.692800392878482e-15
# test: pjnk and PKC given plcg, pakts473 -> pval=2.692498424234253e-15
# test: pjnk and PKC given plcg, PKA -> pval=3.016262578547631e-15
# test: pjnk and PKC given plcg, P38 -> pval=1.511767669234646e-17
# test: pjnk and PKC given PIP2, PIP3 -> pval=2.00710457435191e-15
# test: pjnk and PKC given PIP2, perk -> pval=2.638558396218044e-15
# test: pjnk and PKC given PIP2, pakts473 -> pval=2.6204340844646367e-15
# test: pjnk and PKC given PIP2, PKA -> pval=2.9909958776863177e-15
# test: pjnk and PKC given PIP2, P38 -> pval=1.4240313121916482e-17
# test: pjnk and PKC given PIP3, perk -> pval=2.3015041936184108e-15
# test: pjnk and PKC given PIP3, pakts473 -> pval=2.2834781513644723e-15
# test: pjnk and PKC given PIP3, PKA -> pval=2.6089151141679394e-15
# test: pjnk and PKC given PIP3, P38 -> pval=1.2104287087588089e-17
# test: pjnk and PKC given perk, pakts473 -> pval=2.2134524601737025e-15
# test: pjnk and PKC given perk, PKA -> pval=2.932093507838832e-15
# test: pjnk and PKC given perk, P38 -> pval=1.8822210017819683e-17
# test: pjnk and PKC given pakts473, PKA -> pval=2.957672317073945e-15
# test: pjnk and PKC given pakts473, P38 -> pval=1.5823706513341065e-17
# test: pjnk and PKC given PKA, P38 -> pval=1.6206636171887028e-17
# test: pjnk and P38 given praf, pmek -> pval=0.01488630862730005
# test: pjnk and P38 given praf, plcg -> pval=0.015298583322197861
# test: pjnk and P38 given praf, PIP2 -> pval=0.015465487253469377
# test: pjnk and P38 given praf, PIP3 -> pval=0.015323807788863861
# test: pjnk and P38 given praf, perk -> pval=0.014469859129320289
# test: pjnk and P38 given praf, pakts473 -> pval=0.015441854270180048
# test: pjnk and P38 given praf, PKA -> pval=0.01657478989016558
# test: pjnk and P38 given praf, PKC -> pval=5.73927826347539e-05
# test: pjnk and P38 given pmek, plcg -> pval=0.012098310003579889
# test: pjnk and P38 given pmek, PIP2 -> pval=0.012163666942439071
# test: pjnk and P38 given pmek, PIP3 -> pval=0.012018007552021296
# test: pjnk and P38 given pmek, perk -> pval=0.01145648151047626
# test: pjnk and P38 given pmek, pakts473 -> pval=0.012194962479935378
# test: pjnk and P38 given pmek, PKA -> pval=0.013091175504861765
# test: pjnk and P38 given pmek, PKC -> pval=6.79776468940501e-05
# test: pjnk and P38 given plcg, PIP2 -> pval=0.014244885915887316
# test: pjnk and P38 given plcg, PIP3 -> pval=0.014169296577645403
# test: pjnk and P38 given plcg, perk -> pval=0.013246703896689773
# test: pjnk and P38 given plcg, pakts473 -> pval=0.014217108572180115
# test: pjnk and P38 given plcg, PKA -> pval=0.015209356234890128
# test: pjnk and P38 given plcg, PKC -> pval=6.27000094576056e-05
# test: pjnk and P38 given PIP2, PIP3 -> pval=0.014271355839549615
# test: pjnk and P38 given PIP2, perk -> pval=0.013361350722358516
# test: pjnk and P38 given PIP2, pakts473 -> pval=0.014295897201945762
# test: pjnk and P38 given PIP2, PKA -> pval=0.01531402717093976
# test: pjnk and P38 given PIP2, PKC -> pval=6.039855307374888e-05
# test: pjnk and P38 given PIP3, perk -> pval=0.01333249155913665
# test: pjnk and P38 given PIP3, pakts473 -> pval=0.01422127370587823
# test: pjnk and P38 given PIP3, PKA -> pval=0.015225485289473581
# test: pjnk and P38 given PIP3, PKC -> pval=5.822292096585139e-05
# test: pjnk and P38 given perk, pakts473 -> pval=0.012532255198454325
# test: pjnk and P38 given perk, PKA -> pval=0.014293542412760768
# test: pjnk and P38 given perk, PKC -> pval=7.024278852290253e-05
# test: pjnk and P38 given pakts473, PKA -> pval=0.015259259788695448
# test: pjnk and P38 given pakts473, PKC -> pval=6.251012143297801e-05
# test: pjnk and P38 given PKA, PKC -> pval=5.9695397479464615e-05
# {frozenset({0, 2}): (), frozenset({0, 3}): (), frozenset({0, 4}): (), frozenset({0, 5}): (), frozenset({0, 6}): (), frozenset({0, 7}): (), frozenset({0, 8}): (), frozenset({0, 10}): (), frozenset({1, 2}): (), frozenset({1, 3}): (), frozenset({1, 5}): (), frozenset({1, 6}): (), frozenset({1, 7}): (), frozenset({8, 1}): (), frozenset({1, 9}): (), frozenset({1, 10}): (), frozenset({2, 5}): (), frozenset({2, 6}): (), frozenset({2, 7}): (), frozenset({8, 2}): (), frozenset({9, 2}): (), frozenset({3, 5}): (), frozenset({3, 6}): (), frozenset({3, 7}): (), frozenset({8, 3}): (), frozenset({9, 3}): (), frozenset({10, 3}): (), frozenset({4, 5}): (), frozenset({4, 6}): (), frozenset({4, 7}): (), frozenset({8, 4}): (), frozenset({9, 4}): (), frozenset({10, 4}): (), frozenset({8, 5}): (), frozenset({9, 5}): (), frozenset({10, 5}): (), frozenset({8, 6}): (), frozenset({9, 6}): (), frozenset({10, 6}): (), frozenset({8, 7}): (), frozenset({9, 7}): (), frozenset({10, 7}): (), frozenset({0, 9}): (1,), frozenset({2, 3}): (4,), frozenset({5, 7}): (6,)}

# %% [markdown]
# Now let's look at what else is in the dataset: the interventional data corresponding to different experiments. The PC algorithm did not look at this part of the dataset, but these additional experiments can obviously provide valuable information about the causal graph. In the following questions, we will investigate two examples of this. We will use the output of the PC algorithm to give us a rough idea of what the causal graph might look like.
#
# The interventions in these experiment are not perfect interventions: they change the structural equation of a variable, but not by setting it to a constant. The new structural equation in the intervened model may still include all variables that were there in the original model. So in the graph of the intervened model, all arrows will still be there.
#
# Further, some of the interventions change not one, but multiple structural equations.
#
# For some of the interventions in the data, here is what they do according to many (but not all) experts:
# * experiment 5 adds the substance psitectorigenin, which modifies the amount of PIP2;
# * experiment 6 adds the substance U0126, which increases the *activity* of pmek. This means that the amount of pmek is not changed by the intervention, but for all *children* of pmek in the causal model, the structural equation changes to reflect that pmek now has a stronger effect on them. pmek is believed to have only one child in the true causal model, namely perk.
#
# (Source: Mooij et al., 2019, specifically Tables 2 & 3 and Figure 35(a))

# %% [markdown]
# Create two new dataframes, one containing all data from experiments 1 and 5, and one with the data from experiments 1 and 6. These dataframes should still have an 'experiment' column, so that you can tell for each row whether it came from the observational or the interventional dataset.

# %%
# Your code here (0.5 point)
experiment_data_1_and_5 = all_data.loc[(all_data['experiment'] == 1) | (all_data['experiment'] == 5)]
experiment_data_1_and_5 = experiment_data_1_and_5.iloc[:, :-1]

experiment_data_1_and_6 = all_data.loc[(all_data['experiment'] == 1) | (all_data['experiment'] == 6)]
experiment_data_1_and_6 = experiment_data_1_and_6.iloc[:, :-1]

print(experiment_data_1_and_6.head)
# Out:
# <bound method NDFrame.head of           praf      pmek      plcg      PIP2      PIP3      perk  pakts473  \
# 0     3.594569  3.144152  2.934920  3.342862  4.231204  2.810005  3.295837
# 1     3.826465  3.277145  3.104587  3.288402  2.897568  3.353407  3.749504
# 2     4.239887  3.990834  3.202746  3.005683  3.135494  3.214868  3.749504
# 3     4.418841  4.530447  3.499533  3.157000  2.423917  2.761907  3.081910
# 4     3.777348  3.394508  2.720637  2.982140  3.549617  3.437208  4.027136
# ...        ...       ...       ...       ...       ...       ...       ...
# 4993  4.216562  4.619073  3.303217  3.246491  2.806386  2.702032  3.811097
# 4994  5.874931  6.403574  3.246491  3.095578  3.387774  2.397895  4.231204
# 4995  4.859812  5.117994  3.157000  4.875197  3.918005  2.540814  4.072440
# 4996  5.459586  5.899897  3.273364  3.401197  2.955951  3.417727  5.379897
# 4997  4.795791  5.056246  2.623944  3.030134  3.681351  2.870169  4.094345
#
#            PKA       PKC       P38      pjnk
# 0     6.049733  3.295837  4.005513  3.912023
# 1     5.891644  2.593013  3.277145  4.269697
# 2     6.023448  3.063391  3.735286  3.384390
# 3     6.287859  3.165475  3.653252  3.499533
# 4     5.752573  2.685123  3.575151  4.514151
# ...        ...       ...       ...       ...
# 4993  4.882802  2.426571  3.407842  2.673459
# 4994  5.123964  2.466403  3.742420  2.662355
# 4995  5.204007  3.100092  3.668677  3.881564
# 4996  8.017308  3.430756  4.546481  4.036009
# 4997  6.989335  2.494032  3.394508  2.548664
#
# [1652 rows x 11 columns]>

# %% [markdown]
# **Question (1.5 points)**: In the dataframe for experiments 1 and 5, look at PIP2 and a variable adjacent to it in the output of PC (if there is more than one, pick one). Using about 200 words, answer the following questions: Based on looking at one or more plots (like scatterplots or histograms), which do you find more likely: that psitectorigenin directly modifies PIP2, or the neighbouring variable, or both? And what does the data for the two experiments seem to say about the direction of the arrow between PIP2 and its neighbour?
#
# Insert one or more markdown and code boxes below here to give your answer and the plots you base your answer on. (Please put your answer in markdown boxes, not as comments in your code!)

# %% [markdown]
# **Question (1.5 points)**: In the dataframe for experiments 1 and 6, look at pmek, perk, and any other variables adjacent to pmek in the output of PC. Assume it is true that adding U0126 produces an intervention on the *activity* of pmek. What would you expect to see in the data if the graph found by PC was correct? Would you propose any changes to that graph based on the data?
#
# Again put your answer (about 200 words) with accompanying plots in new boxes below here.

# %% [markdown]
# ---
#
# You are almost done! Before handing in, make sure that the code you hand in works, and that all plots are shown. **Submit just one file per team.** Name the submitted file according to your and your collaborator's last name (`submitter_collaborator.ipynb`).

# %% [markdown]
# ### References
# * J. M. Mooij, S. Magliacane, and T. Claassen, "Joint Causal Inference from Multiple Contexts," [arXiv:1611.10351v4](https://arxiv.org/abs/1611.10351), 2019.
# * J. Runge, "Conditional Independence Testing Based on a Nearest-Neighbor Estimator of Conditional Mutual Information" In Proceedings of the 21st International Conference on Artificial Intelligence and Statistics, http://proceedings.mlr.press/v84/runge18a.html, 2018.
# * K. Sachs, O. Perez, D. Pe’er, D. A. Lauffenburger, and G. P. Nolan, "Causal protein-signaling networks derived from multiparameter single-cell data," Science, vol. 308, no. 5721, pp. 523–529, 2005.
